# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 8
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 8:
# Image - Min Value: 31 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 0 Name: airplane

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return np.divide(x, 255)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    return  np.eye(10)[x]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# If you're finding it hard to dedicate enough time for this course a week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) to build each layer, except "Convolutional & Max Pooling" layer.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# If you would like to get the most of this course, try to solve all the problems without TF Layers.  Let's begin!
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None, image_shape[0], image_shape[1], image_shape[2]), name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None, n_classes), name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=None, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# Note: You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.  You're free to use any TensorFlow package for all the other layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    #print("conv size:" ,conv_ksize[0], conv_ksize[1])
    #print("input size", x_tensor.shape[3].value)
    #print("ouptut size", conv_num_outputs)
    weights = tf.Variable(tf.random_normal([conv_ksize[0], conv_ksize[1],x_tensor.shape[3].value, conv_num_outputs], stddev=0.1))
    biases = tf.Variable(tf.random_normal([conv_num_outputs], stddev=0.1))
    strides_dim = [1, conv_strides[0],conv_strides[1], 1]
    x_tensor = tf.nn.conv2d(x_tensor, weights, strides= strides_dim, padding='SAME')
    x_tensor = tf.nn.bias_add(x_tensor, biases)
    x_tensor = tf.nn.relu(x_tensor)
    pool_ksize_dim = [1, pool_ksize[0],pool_ksize[1], 1]
    pool_strides_dim = [1, pool_strides[0],pool_strides[1], 1]
    x_tensor =  tf.nn.max_pool(x_tensor, ksize=pool_ksize_dim, strides=pool_strides_dim,padding='SAME')
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    nW = x_tensor.shape[1].value
    nL = x_tensor.shape[2].value
    nD = x_tensor.shape[3].value
    nx = nW*nL*nD
    #return tf.reshape(x_tensor,[-1,nx])
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    #weight = tf.Variable(tf.random_normal([x_tensor.shape[-1].value, num_outputs]))
    #bias = tf.Variable(tf.zeros([num_outputs]))
    #x_tensor = tf.add(tf.matmul(x_tensor, weight), bias)
    #
    x_tensor = tf.contrib.layers.fully_connected(x_tensor,num_outputs)
    return tf.nn.relu(x_tensor)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.
#
# Note: Activation, softmax, or cross entropy shouldn't be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    #print(x_tensor.shape[-1].value)
    weight = tf.Variable(tf.random_normal([x_tensor.shape[-1].value, num_outputs], stddev=0.1))
    bias = tf.Variable(tf.random_normal([num_outputs], stddev=0.1))
    return tf.add(tf.matmul(x_tensor, weight), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    
    
    num_outputs = 10
    #x = conv2d_maxpool(x, 16, (3,3), (1,1), (1,1), (1,1))
    #x = conv2d_maxpool(x, 16, (3,3), (1,1), (2,2), (2,2))
    x = conv2d_maxpool(x, 32, (3,3), (1,1), (2,2), (2,2))
    #x = tf.layers.dropout(x,rate=keep_prob)
    x = conv2d_maxpool(x, 64, (3,3), (1,1), (2,2), (2,2))
    #x = tf.layers.dropout(x,rate=keep_prob)
    #x = tf.layers.dropout(x,rate=keep_prob)
    x = conv2d_maxpool(x, 128, (3,3), (1,1), (2,2), (2,2))
    x = tf.layers.dropout(x,rate=keep_prob)
    x = conv2d_maxpool(x, 256, (2,2), (1,1), (2,2), (2,2))
    x = tf.layers.dropout(x,rate=keep_prob)
    x = conv2d_maxpool(x, 512, (2,2), (1,1), (2,2), (2,2))
    x = tf.layers.dropout(x,rate=keep_prob)
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    x = flatten(x)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:

    x = fully_conn(x, 512)
    x = tf.layers.dropout(x,rate=keep_prob)
    
    x = fully_conn(x, 256)
    x = tf.layers.dropout(x,rate=keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    out = output(x, num_outputs)
    
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    #print("keep_probability", keep_probability)
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch,
                                       keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = sess.run(cost, feed_dict={x: feature_batch,y: label_batch, keep_prob:1.})
    valid_accuracy = sess.run(accuracy, feed_dict={x: valid_features,y: valid_labels, keep_prob: 1.})
    #cost, accuracy = session.run([cost, accuracy], feed_dict={x: feature_batch,
    #                                                         y: label_batch,
    #                                                          keep_prob: 1.})
    print("Cost= " + "{:.5f}".format(loss) + ", Validation Accuracy= " + "{:.5f}".format(valid_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 150
batch_size = 128
keep_probability = 0.3

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost= 1.88360, Validation Accuracy= 0.33120
# Epoch  2, CIFAR-10 Batch 1:  Cost= 1.54962, Validation Accuracy= 0.38360
# Epoch  3, CIFAR-10 Batch 1:  Cost= 1.23104, Validation Accuracy= 0.45760
# Epoch  4, CIFAR-10 Batch 1:  Cost= 0.99371, Validation Accuracy= 0.48340
# Epoch  5, CIFAR-10 Batch 1:  Cost= 0.88654, Validation Accuracy= 0.50740
# Epoch  6, CIFAR-10 Batch 1:  Cost= 0.72690, Validation Accuracy= 0.47920
# Epoch  7, CIFAR-10 Batch 1:  Cost= 0.52622, Validation Accuracy= 0.49900
# Epoch  8, CIFAR-10 Batch 1:  Cost= 0.49254, Validation Accuracy= 0.53100
# Epoch  9, CIFAR-10 Batch 1:  Cost= 0.45479, Validation Accuracy= 0.51960
# Epoch 10, CIFAR-10 Batch 1:  Cost= 0.24177, Validation Accuracy= 0.53320
# Epoch 11, CIFAR-10 Batch 1:  Cost= 0.21978, Validation Accuracy= 0.53900
# Epoch 12, CIFAR-10 Batch 1:  Cost= 0.17653, Validation Accuracy= 0.55600
# Epoch 13, CIFAR-10 Batch 1:  Cost= 0.19695, Validation Accuracy= 0.54460
# Epoch 14, CIFAR-10 Batch 1:  Cost= 0.13099, Validation Accuracy= 0.54000
# Epoch 15, CIFAR-10 Batch 1:  Cost= 0.09962, Validation Accuracy= 0.52020
# Epoch 16, CIFAR-10 Batch 1:  Cost= 0.08021, Validation Accuracy= 0.53700
# Epoch 17, CIFAR-10 Batch 1:  Cost= 0.16063, Validation Accuracy= 0.51000
# Epoch 18, CIFAR-10 Batch 1:  Cost= 0.02858, Validation Accuracy= 0.55520
# Epoch 19, CIFAR-10 Batch 1:  Cost= 0.02988, Validation Accuracy= 0.55100
# Epoch 20, CIFAR-10 Batch 1:  Cost= 0.03493, Validation Accuracy= 0.53480
# Epoch 21, CIFAR-10 Batch 1:  Cost= 0.01495, Validation Accuracy= 0.53500
# Epoch 22, CIFAR-10 Batch 1:  Cost= 0.03097, Validation Accuracy= 0.52700
# Epoch 23, CIFAR-10 Batch 1:  Cost= 0.01379, Validation Accuracy= 0.56340
# Epoch 24, CIFAR-10 Batch 1:  Cost= 0.01069, Validation Accuracy= 0.56560
# Epoch 25, CIFAR-10 Batch 1:  Cost= 0.00509, Validation Accuracy= 0.54420
# Epoch 26, CIFAR-10 Batch 1:  Cost= 0.00449, Validation Accuracy= 0.54460
# Epoch 27, CIFAR-10 Batch 1:  Cost= 0.00544, Validation Accuracy= 0.56400
# Epoch 28, CIFAR-10 Batch 1:  Cost= 0.00236, Validation Accuracy= 0.57320
# Epoch 29, CIFAR-10 Batch 1:  Cost= 0.00806, Validation Accuracy= 0.54120
# Epoch 30, CIFAR-10 Batch 1:  Cost= 0.00165, Validation Accuracy= 0.56480
# Epoch 31, CIFAR-10 Batch 1:  Cost= 0.00570, Validation Accuracy= 0.55980
# Epoch 32, CIFAR-10 Batch 1:  Cost= 0.00119, Validation Accuracy= 0.56400
# Epoch 33, CIFAR-10 Batch 1:  Cost= 0.00097, Validation Accuracy= 0.56720
# Epoch 34, CIFAR-10 Batch 1:  Cost= 0.00103, Validation Accuracy= 0.56220
# Epoch 35, CIFAR-10 Batch 1:  Cost= 0.00049, Validation Accuracy= 0.54980
# Epoch 36, CIFAR-10 Batch 1:  Cost= 0.00121, Validation Accuracy= 0.55680
# Epoch 37, CIFAR-10 Batch 1:  Cost= 0.00287, Validation Accuracy= 0.55700
# Epoch 38, CIFAR-10 Batch 1:  Cost= 0.00070, Validation Accuracy= 0.55980
# Epoch 39, CIFAR-10 Batch 1:  Cost= 0.00081, Validation Accuracy= 0.57100
# Epoch 40, CIFAR-10 Batch 1:  Cost= 0.00166, Validation Accuracy= 0.55900
# Epoch 41, CIFAR-10 Batch 1:  Cost= 0.00114, Validation Accuracy= 0.56220
# Epoch 42, CIFAR-10 Batch 1:  Cost= 0.00131, Validation Accuracy= 0.55080
# Epoch 43, CIFAR-10 Batch 1:  Cost= 0.00221, Validation Accuracy= 0.55840
# Epoch 44, CIFAR-10 Batch 1:  Cost= 0.00249, Validation Accuracy= 0.55740
# Epoch 45, CIFAR-10 Batch 1:  Cost= 0.00123, Validation Accuracy= 0.56660
# Epoch 46, CIFAR-10 Batch 1:  Cost= 0.00129, Validation Accuracy= 0.55720
# Epoch 47, CIFAR-10 Batch 1:  Cost= 0.00109, Validation Accuracy= 0.54340
# Epoch 48, CIFAR-10 Batch 1:  Cost= 0.00315, Validation Accuracy= 0.53500
# Epoch 49, CIFAR-10 Batch 1:  Cost= 0.00338, Validation Accuracy= 0.53600
# Epoch 50, CIFAR-10 Batch 1:  Cost= 0.00268, Validation Accuracy= 0.55340
# Epoch 51, CIFAR-10 Batch 1:  Cost= 0.01262, Validation Accuracy= 0.55580
# Epoch 52, CIFAR-10 Batch 1:  Cost= 0.00108, Validation Accuracy= 0.56560
# Epoch 53, CIFAR-10 Batch 1:  Cost= 0.00203, Validation Accuracy= 0.55520
# Epoch 54, CIFAR-10 Batch 1:  Cost= 0.00054, Validation Accuracy= 0.55160
# Epoch 55, CIFAR-10 Batch 1:  Cost= 0.00032, Validation Accuracy= 0.56120
# Epoch 56, CIFAR-10 Batch 1:  Cost= 0.00152, Validation Accuracy= 0.55680
# Epoch 57, CIFAR-10 Batch 1:  Cost= 0.00443, Validation Accuracy= 0.55020
# Epoch 58, CIFAR-10 Batch 1:  Cost= 0.00230, Validation Accuracy= 0.54280
# Epoch 59, CIFAR-10 Batch 1:  Cost= 0.00092, Validation Accuracy= 0.54740
# Epoch 60, CIFAR-10 Batch 1:  Cost= 0.00266, Validation Accuracy= 0.55720
# Epoch 61, CIFAR-10 Batch 1:  Cost= 0.00123, Validation Accuracy= 0.56180
# Epoch 62, CIFAR-10 Batch 1:  Cost= 0.00093, Validation Accuracy= 0.54320
# Epoch 63, CIFAR-10 Batch 1:  Cost= 0.00055, Validation Accuracy= 0.56340
# Epoch 64, CIFAR-10 Batch 1:  Cost= 0.00027, Validation Accuracy= 0.57960
# Epoch 65, CIFAR-10 Batch 1:  Cost= 0.00148, Validation Accuracy= 0.56880
# Epoch 66, CIFAR-10 Batch 1:  Cost= 0.00112, Validation Accuracy= 0.55380
# Epoch 67, CIFAR-10 Batch 1:  Cost= 0.00053, Validation Accuracy= 0.56140
# Epoch 68, CIFAR-10 Batch 1:  Cost= 0.00063, Validation Accuracy= 0.54280
# Epoch 69, CIFAR-10 Batch 1:  Cost= 0.00295, Validation Accuracy= 0.55200
# Epoch 70, CIFAR-10 Batch 1:  Cost= 0.00112, Validation Accuracy= 0.54820
# Epoch 71, CIFAR-10 Batch 1:  Cost= 0.00342, Validation Accuracy= 0.56340
# Epoch 72, CIFAR-10 Batch 1:  Cost= 0.00089, Validation Accuracy= 0.54340
# Epoch 73, CIFAR-10 Batch 1:  Cost= 0.00102, Validation Accuracy= 0.55420
# Epoch 74, CIFAR-10 Batch 1:  Cost= 0.00088, Validation Accuracy= 0.56320
# Epoch 75, CIFAR-10 Batch 1:  Cost= 0.00201, Validation Accuracy= 0.55360
# Epoch 76, CIFAR-10 Batch 1:  Cost= 0.00098, Validation Accuracy= 0.55720
# Epoch 77, CIFAR-10 Batch 1:  Cost= 0.00021, Validation Accuracy= 0.56180
# Epoch 78, CIFAR-10 Batch 1:  Cost= 0.00237, Validation Accuracy= 0.55720
# Epoch 79, CIFAR-10 Batch 1:  Cost= 0.00103, Validation Accuracy= 0.56480
# Epoch 80, CIFAR-10 Batch 1:  Cost= 0.00081, Validation Accuracy= 0.57020
# Epoch 81, CIFAR-10 Batch 1:  Cost= 0.00039, Validation Accuracy= 0.56500
# Epoch 82, CIFAR-10 Batch 1:  Cost= 0.00171, Validation Accuracy= 0.55480
# Epoch 83, CIFAR-10 Batch 1:  Cost= 0.00071, Validation Accuracy= 0.55060
# Epoch 84, CIFAR-10 Batch 1:  Cost= 0.00152, Validation Accuracy= 0.57160
# Epoch 85, CIFAR-10 Batch 1:  Cost= 0.00125, Validation Accuracy= 0.55840
# Epoch 86, CIFAR-10 Batch 1:  Cost= 0.00051, Validation Accuracy= 0.56680
# Epoch 87, CIFAR-10 Batch 1:  Cost= 0.00062, Validation Accuracy= 0.55840
# Epoch 88, CIFAR-10 Batch 1:  Cost= 0.00111, Validation Accuracy= 0.56780
# Epoch 89, CIFAR-10 Batch 1:  Cost= 0.00097, Validation Accuracy= 0.56040
# Epoch 90, CIFAR-10 Batch 1:  Cost= 0.00013, Validation Accuracy= 0.57180
# Epoch 91, CIFAR-10 Batch 1:  Cost= 0.00006, Validation Accuracy= 0.57820
# Epoch 92, CIFAR-10 Batch 1:  Cost= 0.00608, Validation Accuracy= 0.52860
# Epoch 93, CIFAR-10 Batch 1:  Cost= 0.00386, Validation Accuracy= 0.56740
# Epoch 94, CIFAR-10 Batch 1:  Cost= 0.00043, Validation Accuracy= 0.55540
# Epoch 95, CIFAR-10 Batch 1:  Cost= 0.00125, Validation Accuracy= 0.56140
# Epoch 96, CIFAR-10 Batch 1:  Cost= 0.00054, Validation Accuracy= 0.54260
# Epoch 97, CIFAR-10 Batch 1:  Cost= 0.00072, Validation Accuracy= 0.56300
# Epoch 98, CIFAR-10 Batch 1:  Cost= 0.00077, Validation Accuracy= 0.57460
# Epoch 99, CIFAR-10 Batch 1:  Cost= 0.00071, Validation Accuracy= 0.55180
# Epoch 100, CIFAR-10 Batch 1:  Cost= 0.00037, Validation Accuracy= 0.55940
# Epoch 101, CIFAR-10 Batch 1:  Cost= 0.00054, Validation Accuracy= 0.57360
# Epoch 102, CIFAR-10 Batch 1:  Cost= 0.00015, Validation Accuracy= 0.57280
# Epoch 103, CIFAR-10 Batch 1:  Cost= 0.00004, Validation Accuracy= 0.57780
# Epoch 104, CIFAR-10 Batch 1:  Cost= 0.00028, Validation Accuracy= 0.56860
# Epoch 105, CIFAR-10 Batch 1:  Cost= 0.00062, Validation Accuracy= 0.56860
# Epoch 106, CIFAR-10 Batch 1:  Cost= 0.00028, Validation Accuracy= 0.56220
# Epoch 107, CIFAR-10 Batch 1:  Cost= 0.00013, Validation Accuracy= 0.54780
# Epoch 108, CIFAR-10 Batch 1:  Cost= 0.00353, Validation Accuracy= 0.54220
# Epoch 109, CIFAR-10 Batch 1:  Cost= 0.00091, Validation Accuracy= 0.53780
# Epoch 110, CIFAR-10 Batch 1:  Cost= 0.00058, Validation Accuracy= 0.56000
# Epoch 111, CIFAR-10 Batch 1:  Cost= 0.00092, Validation Accuracy= 0.56340
# Epoch 112, CIFAR-10 Batch 1:  Cost= 0.00029, Validation Accuracy= 0.57620
# Epoch 113, CIFAR-10 Batch 1:  Cost= 0.00003, Validation Accuracy= 0.57420
# Epoch 114, CIFAR-10 Batch 1:  Cost= 0.00013, Validation Accuracy= 0.58080
# Epoch 115, CIFAR-10 Batch 1:  Cost= 0.00023, Validation Accuracy= 0.56760
# Epoch 116, CIFAR-10 Batch 1:  Cost= 0.00004, Validation Accuracy= 0.55340
# Epoch 117, CIFAR-10 Batch 1:  Cost= 0.00035, Validation Accuracy= 0.55240
# Epoch 118, CIFAR-10 Batch 1:  Cost= 0.00041, Validation Accuracy= 0.56760
# Epoch 119, CIFAR-10 Batch 1:  Cost= 0.00103, Validation Accuracy= 0.56580
# Epoch 120, CIFAR-10 Batch 1:  Cost= 0.00052, Validation Accuracy= 0.57120
# Epoch 121, CIFAR-10 Batch 1:  Cost= 0.00058, Validation Accuracy= 0.55720
# Epoch 122, CIFAR-10 Batch 1:  Cost= 0.00012, Validation Accuracy= 0.56860
# Epoch 123, CIFAR-10 Batch 1:  Cost= 0.00009, Validation Accuracy= 0.57160
# Epoch 124, CIFAR-10 Batch 1:  Cost= 0.00013, Validation Accuracy= 0.56660
# Epoch 125, CIFAR-10 Batch 1:  Cost= 0.00056, Validation Accuracy= 0.55860
# Epoch 126, CIFAR-10 Batch 1:  Cost= 0.00015, Validation Accuracy= 0.55920
# Epoch 127, CIFAR-10 Batch 1:  Cost= 0.00255, Validation Accuracy= 0.55680
# Epoch 128, CIFAR-10 Batch 1:  Cost= 0.00035, Validation Accuracy= 0.58700
# Epoch 129, CIFAR-10 Batch 1:  Cost= 0.00011, Validation Accuracy= 0.57460
# Epoch 130, CIFAR-10 Batch 1:  Cost= 0.00004, Validation Accuracy= 0.57180
# Epoch 131, CIFAR-10 Batch 1:  Cost= 0.00033, Validation Accuracy= 0.57060
# Epoch 132, CIFAR-10 Batch 1:  Cost= 0.00006, Validation Accuracy= 0.57380
# Epoch 133, CIFAR-10 Batch 1:  Cost= 0.00049, Validation Accuracy= 0.56340
# Epoch 134, CIFAR-10 Batch 1:  Cost= 0.00038, Validation Accuracy= 0.56880
# Epoch 135, CIFAR-10 Batch 1:  Cost= 0.00025, Validation Accuracy= 0.56620
# Epoch 136, CIFAR-10 Batch 1:  Cost= 0.00052, Validation Accuracy= 0.58680
# Epoch 137, CIFAR-10 Batch 1:  Cost= 0.00027, Validation Accuracy= 0.58200
# Epoch 138, CIFAR-10 Batch 1:  Cost= 0.00006, Validation Accuracy= 0.56440
# Epoch 139, CIFAR-10 Batch 1:  Cost= 0.00028, Validation Accuracy= 0.59120
# Epoch 140, CIFAR-10 Batch 1:  Cost= 0.00659, Validation Accuracy= 0.54520
# Epoch 141, CIFAR-10 Batch 1:  Cost= 0.00007, Validation Accuracy= 0.57980
# Epoch 142, CIFAR-10 Batch 1:  Cost= 0.00014, Validation Accuracy= 0.55520
# Epoch 143, CIFAR-10 Batch 1:  Cost= 0.00033, Validation Accuracy= 0.57500
# Epoch 144, CIFAR-10 Batch 1:  Cost= 0.00020, Validation Accuracy= 0.56320
# Epoch 145, CIFAR-10 Batch 1:  Cost= 0.00029, Validation Accuracy= 0.56340
# Epoch 146, CIFAR-10 Batch 1:  Cost= 0.00081, Validation Accuracy= 0.56420
# Epoch 147, CIFAR-10 Batch 1:  Cost= 0.00009, Validation Accuracy= 0.56980
# Epoch 148, CIFAR-10 Batch 1:  Cost= 0.00063, Validation Accuracy= 0.57760
# Epoch 149, CIFAR-10 Batch 1:  Cost= 0.00011, Validation Accuracy= 0.53700
# Epoch 150, CIFAR-10 Batch 1:  Cost= 0.00022, Validation Accuracy= 0.56680
# Epoch 151, CIFAR-10 Batch 1:  Cost= 0.00011, Validation Accuracy= 0.56620
# Epoch 152, CIFAR-10 Batch 1:  Cost= 0.00093, Validation Accuracy= 0.56900
# Epoch 153, CIFAR-10 Batch 1:  Cost= 0.00047, Validation Accuracy= 0.58020
# Epoch 154, CIFAR-10 Batch 1:  Cost= 0.00052, Validation Accuracy= 0.57400
# Epoch 155, CIFAR-10 Batch 1:  Cost= 0.00113, Validation Accuracy= 0.57200
# Epoch 156, CIFAR-10 Batch 1:  Cost= 0.00009, Validation Accuracy= 0.56500
# Epoch 157, CIFAR-10 Batch 1:  Cost= 0.00035, Validation Accuracy= 0.57640
# Epoch 158, CIFAR-10 Batch 1:  Cost= 0.00163, Validation Accuracy= 0.57360
# Epoch 159, CIFAR-10 Batch 1:  Cost= 0.00347, Validation Accuracy= 0.56260
# Epoch 160, CIFAR-10 Batch 1:  Cost= 0.00045, Validation Accuracy= 0.53920
# Epoch 161, CIFAR-10 Batch 1:  Cost= 0.00012, Validation Accuracy= 0.57000
# Epoch 162, CIFAR-10 Batch 1:  Cost= 0.00039, Validation Accuracy= 0.57080
# Epoch 163, CIFAR-10 Batch 1:  Cost= 0.00014, Validation Accuracy= 0.56520
# Epoch 164, CIFAR-10 Batch 1:  Cost= 0.00091, Validation Accuracy= 0.56520
# Epoch 165, CIFAR-10 Batch 1:  Cost= 0.00009, Validation Accuracy= 0.58200
# Epoch 166, CIFAR-10 Batch 1:  Cost= 0.00009, Validation Accuracy= 0.56920
# Epoch 167, CIFAR-10 Batch 1:  Cost= 0.00021, Validation Accuracy= 0.56980
# Epoch 168, CIFAR-10 Batch 1:  Cost= 0.00035, Validation Accuracy= 0.57400
# Epoch 169, CIFAR-10 Batch 1:  Cost= 0.00007, Validation Accuracy= 0.58220
# Epoch 170, CIFAR-10 Batch 1:  Cost= 0.00028, Validation Accuracy= 0.57620
# Epoch 171, CIFAR-10 Batch 1:  Cost= 0.00005, Validation Accuracy= 0.58220
# Epoch 172, CIFAR-10 Batch 1:  Cost= 0.00001, Validation Accuracy= 0.59060
# Epoch 173, CIFAR-10 Batch 1:  Cost= 0.00069, Validation Accuracy= 0.57780
# Epoch 174, CIFAR-10 Batch 1:  Cost= 0.00001, Validation Accuracy= 0.58120
# Epoch 175, CIFAR-10 Batch 1:  Cost= 0.00033, Validation Accuracy= 0.56060
# Epoch 176, CIFAR-10 Batch 1:  Cost= 0.00038, Validation Accuracy= 0.55720
# Epoch 177, CIFAR-10 Batch 1:  Cost= 0.00037, Validation Accuracy= 0.56380
# Epoch 178, CIFAR-10 Batch 1:  Cost= 0.00010, Validation Accuracy= 0.55520
# Epoch 179, CIFAR-10 Batch 1:  Cost= 0.00058, Validation Accuracy= 0.55200
# Epoch 180, CIFAR-10 Batch 1:  Cost= 0.00024, Validation Accuracy= 0.56360
# Epoch 181, CIFAR-10 Batch 1:  Cost= 0.00011, Validation Accuracy= 0.56000
# Epoch 182, CIFAR-10 Batch 1:  Cost= 0.00279, Validation Accuracy= 0.55480
# Epoch 183, CIFAR-10 Batch 1:  Cost= 0.00050, Validation Accuracy= 0.55860
# Epoch 184, CIFAR-10 Batch 1:  Cost= 0.00057, Validation Accuracy= 0.56080
# Epoch 185, CIFAR-10 Batch 1:  Cost= 0.00004, Validation Accuracy= 0.57340
# Epoch 186, CIFAR-10 Batch 1:  Cost= 0.00036, Validation Accuracy= 0.57380
# Epoch 187, CIFAR-10 Batch 1:  Cost= 0.00057, Validation Accuracy= 0.56380
# Epoch 188, CIFAR-10 Batch 1:  Cost= 0.00009, Validation Accuracy= 0.56640
# Epoch 189, CIFAR-10 Batch 1:  Cost= 0.00008, Validation Accuracy= 0.57340
# Epoch 190, CIFAR-10 Batch 1:  Cost= 0.00031, Validation Accuracy= 0.57020
# Epoch 191, CIFAR-10 Batch 1:  Cost= 0.00001, Validation Accuracy= 0.58720
# Epoch 192, CIFAR-10 Batch 1:  Cost= 0.00016, Validation Accuracy= 0.56620
# Epoch 193, CIFAR-10 Batch 1:  Cost= 0.00272, Validation Accuracy= 0.56980
# Epoch 194, CIFAR-10 Batch 1:  Cost= 0.00014, Validation Accuracy= 0.56540
# Epoch 195, CIFAR-10 Batch 1:  Cost= 0.00000, Validation Accuracy= 0.56580
# Epoch 196, CIFAR-10 Batch 1:  Cost= 0.00004, Validation Accuracy= 0.56740
# Epoch 197, CIFAR-10 Batch 1:  Cost= 0.00001, Validation Accuracy= 0.57580
# Epoch 198, CIFAR-10 Batch 1:  Cost= 0.00062, Validation Accuracy= 0.56440
# Epoch 199, CIFAR-10 Batch 1:  Cost= 0.00096, Validation Accuracy= 0.56020
# Epoch 200, CIFAR-10 Batch 1:  Cost= 0.00004, Validation Accuracy= 0.57660

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost= 1.96341, Validation Accuracy= 0.33880
# Epoch  1, CIFAR-10 Batch 2:  Cost= 1.53222, Validation Accuracy= 0.43080
# Epoch  1, CIFAR-10 Batch 3:  Cost= 1.17094, Validation Accuracy= 0.49780
# Epoch  1, CIFAR-10 Batch 4:  Cost= 1.26229, Validation Accuracy= 0.49900
# Epoch  1, CIFAR-10 Batch 5:  Cost= 1.31615, Validation Accuracy= 0.53840
# Epoch  2, CIFAR-10 Batch 1:  Cost= 1.20279, Validation Accuracy= 0.54100
# Epoch  2, CIFAR-10 Batch 2:  Cost= 1.07734, Validation Accuracy= 0.53680
# Epoch  2, CIFAR-10 Batch 3:  Cost= 0.78157, Validation Accuracy= 0.59540
# Epoch  2, CIFAR-10 Batch 4:  Cost= 0.85857, Validation Accuracy= 0.58140
# Epoch  2, CIFAR-10 Batch 5:  Cost= 0.91746, Validation Accuracy= 0.61760
# Epoch  3, CIFAR-10 Batch 1:  Cost= 0.92333, Validation Accuracy= 0.59380
# Epoch  3, CIFAR-10 Batch 2:  Cost= 0.78603, Validation Accuracy= 0.58340
# Epoch  3, CIFAR-10 Batch 3:  Cost= 0.57622, Validation Accuracy= 0.63280
# Epoch  3, CIFAR-10 Batch 4:  Cost= 0.59516, Validation Accuracy= 0.63640
# Epoch  3, CIFAR-10 Batch 5:  Cost= 0.61603, Validation Accuracy= 0.63840
# Epoch  4, CIFAR-10 Batch 1:  Cost= 0.73587, Validation Accuracy= 0.62680
# Epoch  4, CIFAR-10 Batch 2:  Cost= 0.44554, Validation Accuracy= 0.64360
# Epoch  4, CIFAR-10 Batch 3:  Cost= 0.36635, Validation Accuracy= 0.64120
# Epoch  4, CIFAR-10 Batch 4:  Cost= 0.46645, Validation Accuracy= 0.65000
# Epoch  4, CIFAR-10 Batch 5:  Cost= 0.39564, Validation Accuracy= 0.65380
# Epoch  5, CIFAR-10 Batch 1:  Cost= 0.54282, Validation Accuracy= 0.65720
# Epoch  5, CIFAR-10 Batch 2:  Cost= 0.32249, Validation Accuracy= 0.67120
# Epoch  5, CIFAR-10 Batch 3:  Cost= 0.33354, Validation Accuracy= 0.66600
# Epoch  5, CIFAR-10 Batch 4:  Cost= 0.37635, Validation Accuracy= 0.66120
# Epoch  5, CIFAR-10 Batch 5:  Cost= 0.29598, Validation Accuracy= 0.67060
# Epoch  6, CIFAR-10 Batch 1:  Cost= 0.49466, Validation Accuracy= 0.64660
# Epoch  6, CIFAR-10 Batch 2:  Cost= 0.26119, Validation Accuracy= 0.67480
# Epoch  6, CIFAR-10 Batch 3:  Cost= 0.20948, Validation Accuracy= 0.65400
# Epoch  6, CIFAR-10 Batch 4:  Cost= 0.25604, Validation Accuracy= 0.66120
# Epoch  6, CIFAR-10 Batch 5:  Cost= 0.19508, Validation Accuracy= 0.66120
# Epoch  7, CIFAR-10 Batch 1:  Cost= 0.27165, Validation Accuracy= 0.66020
# Epoch  7, CIFAR-10 Batch 2:  Cost= 0.18003, Validation Accuracy= 0.65440
# Epoch  7, CIFAR-10 Batch 3:  Cost= 0.16674, Validation Accuracy= 0.61680
# Epoch  7, CIFAR-10 Batch 4:  Cost= 0.22380, Validation Accuracy= 0.65040
# Epoch  7, CIFAR-10 Batch 5:  Cost= 0.10465, Validation Accuracy= 0.68440
# Epoch  8, CIFAR-10 Batch 1:  Cost= 0.22238, Validation Accuracy= 0.65200
# Epoch  8, CIFAR-10 Batch 2:  Cost= 0.16008, Validation Accuracy= 0.64460
# Epoch  8, CIFAR-10 Batch 3:  Cost= 0.12138, Validation Accuracy= 0.65240
# Epoch  8, CIFAR-10 Batch 4:  Cost= 0.16472, Validation Accuracy= 0.66600
# Epoch  8, CIFAR-10 Batch 5:  Cost= 0.09378, Validation Accuracy= 0.67220
# Epoch  9, CIFAR-10 Batch 1:  Cost= 0.13986, Validation Accuracy= 0.66500
# Epoch  9, CIFAR-10 Batch 2:  Cost= 0.08005, Validation Accuracy= 0.67440
# Epoch  9, CIFAR-10 Batch 3:  Cost= 0.10092, Validation Accuracy= 0.68480
# Epoch  9, CIFAR-10 Batch 4:  Cost= 0.11681, Validation Accuracy= 0.67000
# Epoch  9, CIFAR-10 Batch 5:  Cost= 0.08687, Validation Accuracy= 0.66240
# Epoch 10, CIFAR-10 Batch 1:  Cost= 0.09817, Validation Accuracy= 0.67420
# Epoch 10, CIFAR-10 Batch 2:  Cost= 0.07154, Validation Accuracy= 0.66300
# Epoch 10, CIFAR-10 Batch 3:  Cost= 0.04589, Validation Accuracy= 0.67500
# Epoch 10, CIFAR-10 Batch 4:  Cost= 0.07532, Validation Accuracy= 0.64440
# Epoch 10, CIFAR-10 Batch 5:  Cost= 0.13010, Validation Accuracy= 0.65380
# Epoch 11, CIFAR-10 Batch 1:  Cost= 0.09048, Validation Accuracy= 0.66300
# Epoch 11, CIFAR-10 Batch 2:  Cost= 0.07243, Validation Accuracy= 0.61700
# Epoch 11, CIFAR-10 Batch 3:  Cost= 0.03634, Validation Accuracy= 0.68940
# Epoch 11, CIFAR-10 Batch 4:  Cost= 0.09010, Validation Accuracy= 0.64740
# Epoch 11, CIFAR-10 Batch 5:  Cost= 0.09441, Validation Accuracy= 0.65040
# Epoch 12, CIFAR-10 Batch 1:  Cost= 0.03771, Validation Accuracy= 0.68420
# Epoch 12, CIFAR-10 Batch 2:  Cost= 0.05381, Validation Accuracy= 0.62640
# Epoch 12, CIFAR-10 Batch 3:  Cost= 0.06448, Validation Accuracy= 0.67040
# Epoch 12, CIFAR-10 Batch 4:  Cost= 0.09688, Validation Accuracy= 0.64600
# Epoch 12, CIFAR-10 Batch 5:  Cost= 0.03565, Validation Accuracy= 0.65920
# Epoch 13, CIFAR-10 Batch 1:  Cost= 0.03078, Validation Accuracy= 0.68140
# Epoch 13, CIFAR-10 Batch 2:  Cost= 0.02541, Validation Accuracy= 0.65640
# Epoch 13, CIFAR-10 Batch 3:  Cost= 0.03505, Validation Accuracy= 0.67100
# Epoch 13, CIFAR-10 Batch 4:  Cost= 0.06426, Validation Accuracy= 0.67380
# Epoch 13, CIFAR-10 Batch 5:  Cost= 0.03003, Validation Accuracy= 0.65880
# Epoch 14, CIFAR-10 Batch 1:  Cost= 0.02671, Validation Accuracy= 0.68800
# Epoch 14, CIFAR-10 Batch 2:  Cost= 0.01500, Validation Accuracy= 0.65740
# Epoch 14, CIFAR-10 Batch 3:  Cost= 0.02597, Validation Accuracy= 0.66920
# Epoch 14, CIFAR-10 Batch 4:  Cost= 0.03443, Validation Accuracy= 0.65920
# Epoch 14, CIFAR-10 Batch 5:  Cost= 0.01688, Validation Accuracy= 0.66380
# Epoch 15, CIFAR-10 Batch 1:  Cost= 0.02472, Validation Accuracy= 0.67700
# Epoch 15, CIFAR-10 Batch 2:  Cost= 0.01090, Validation Accuracy= 0.67200
# Epoch 15, CIFAR-10 Batch 3:  Cost= 0.01270, Validation Accuracy= 0.68240
# Epoch 15, CIFAR-10 Batch 4:  Cost= 0.02192, Validation Accuracy= 0.67340
# Epoch 15, CIFAR-10 Batch 5:  Cost= 0.01637, Validation Accuracy= 0.67360
# Epoch 16, CIFAR-10 Batch 1:  Cost= 0.01442, Validation Accuracy= 0.68940
# Epoch 16, CIFAR-10 Batch 2:  Cost= 0.00876, Validation Accuracy= 0.65420
# Epoch 16, CIFAR-10 Batch 3:  Cost= 0.02746, Validation Accuracy= 0.65100
# Epoch 16, CIFAR-10 Batch 4:  Cost= 0.01198, Validation Accuracy= 0.65740
# Epoch 16, CIFAR-10 Batch 5:  Cost= 0.01256, Validation Accuracy= 0.68420
# Epoch 17, CIFAR-10 Batch 1:  Cost= 0.02209, Validation Accuracy= 0.66220
# Epoch 17, CIFAR-10 Batch 2:  Cost= 0.01569, Validation Accuracy= 0.66600
# Epoch 17, CIFAR-10 Batch 3:  Cost= 0.00635, Validation Accuracy= 0.66420
# Epoch 17, CIFAR-10 Batch 4:  Cost= 0.01368, Validation Accuracy= 0.65880
# Epoch 17, CIFAR-10 Batch 5:  Cost= 0.00886, Validation Accuracy= 0.68420
# Epoch 18, CIFAR-10 Batch 1:  Cost= 0.01759, Validation Accuracy= 0.66440
# Epoch 18, CIFAR-10 Batch 2:  Cost= 0.01037, Validation Accuracy= 0.67000
# Epoch 18, CIFAR-10 Batch 3:  Cost= 0.01077, Validation Accuracy= 0.64720
# Epoch 18, CIFAR-10 Batch 4:  Cost= 0.01398, Validation Accuracy= 0.66160
# Epoch 18, CIFAR-10 Batch 5:  Cost= 0.01047, Validation Accuracy= 0.66240
# Epoch 19, CIFAR-10 Batch 1:  Cost= 0.01591, Validation Accuracy= 0.67720
# Epoch 19, CIFAR-10 Batch 2:  Cost= 0.00682, Validation Accuracy= 0.69000
# Epoch 19, CIFAR-10 Batch 3:  Cost= 0.00558, Validation Accuracy= 0.64040
# Epoch 19, CIFAR-10 Batch 4:  Cost= 0.01328, Validation Accuracy= 0.65920
# Epoch 19, CIFAR-10 Batch 5:  Cost= 0.02119, Validation Accuracy= 0.67820
# Epoch 20, CIFAR-10 Batch 1:  Cost= 0.00697, Validation Accuracy= 0.67400
# Epoch 20, CIFAR-10 Batch 2:  Cost= 0.00368, Validation Accuracy= 0.69380
# Epoch 20, CIFAR-10 Batch 3:  Cost= 0.00483, Validation Accuracy= 0.67260
# Epoch 20, CIFAR-10 Batch 4:  Cost= 0.01423, Validation Accuracy= 0.67600
# Epoch 20, CIFAR-10 Batch 5:  Cost= 0.00633, Validation Accuracy= 0.67980
# Epoch 21, CIFAR-10 Batch 1:  Cost= 0.00825, Validation Accuracy= 0.65700
# Epoch 21, CIFAR-10 Batch 2:  Cost= 0.00464, Validation Accuracy= 0.69440
# Epoch 21, CIFAR-10 Batch 3:  Cost= 0.00307, Validation Accuracy= 0.67600
# Epoch 21, CIFAR-10 Batch 4:  Cost= 0.00618, Validation Accuracy= 0.66940
# Epoch 21, CIFAR-10 Batch 5:  Cost= 0.00483, Validation Accuracy= 0.66340
# Epoch 22, CIFAR-10 Batch 1:  Cost= 0.01477, Validation Accuracy= 0.68080
# Epoch 22, CIFAR-10 Batch 2:  Cost= 0.00208, Validation Accuracy= 0.68480
# Epoch 22, CIFAR-10 Batch 3:  Cost= 0.00521, Validation Accuracy= 0.68500
# Epoch 22, CIFAR-10 Batch 4:  Cost= 0.00313, Validation Accuracy= 0.68500
# Epoch 22, CIFAR-10 Batch 5:  Cost= 0.00448, Validation Accuracy= 0.67060
# Epoch 23, CIFAR-10 Batch 1:  Cost= 0.00916, Validation Accuracy= 0.68000
# Epoch 23, CIFAR-10 Batch 2:  Cost= 0.00141, Validation Accuracy= 0.68300
# Epoch 23, CIFAR-10 Batch 3:  Cost= 0.00666, Validation Accuracy= 0.68600
# Epoch 23, CIFAR-10 Batch 4:  Cost= 0.00198, Validation Accuracy= 0.69020
# Epoch 23, CIFAR-10 Batch 5:  Cost= 0.00214, Validation Accuracy= 0.68340
# Epoch 24, CIFAR-10 Batch 1:  Cost= 0.00490, Validation Accuracy= 0.67320
# Epoch 24, CIFAR-10 Batch 2:  Cost= 0.00210, Validation Accuracy= 0.67740
# Epoch 24, CIFAR-10 Batch 3:  Cost= 0.00098, Validation Accuracy= 0.69440
# Epoch 24, CIFAR-10 Batch 4:  Cost= 0.00605, Validation Accuracy= 0.69300
# Epoch 24, CIFAR-10 Batch 5:  Cost= 0.00133, Validation Accuracy= 0.69340
# Epoch 25, CIFAR-10 Batch 1:  Cost= 0.00637, Validation Accuracy= 0.68360
# Epoch 25, CIFAR-10 Batch 2:  Cost= 0.00230, Validation Accuracy= 0.67680
# Epoch 25, CIFAR-10 Batch 3:  Cost= 0.00245, Validation Accuracy= 0.69420
# Epoch 25, CIFAR-10 Batch 4:  Cost= 0.00433, Validation Accuracy= 0.69800
# Epoch 25, CIFAR-10 Batch 5:  Cost= 0.00432, Validation Accuracy= 0.66300
# Epoch 26, CIFAR-10 Batch 1:  Cost= 0.00730, Validation Accuracy= 0.68800
# Epoch 26, CIFAR-10 Batch 2:  Cost= 0.00160, Validation Accuracy= 0.66660
# Epoch 26, CIFAR-10 Batch 3:  Cost= 0.00113, Validation Accuracy= 0.69900
# Epoch 26, CIFAR-10 Batch 4:  Cost= 0.00734, Validation Accuracy= 0.67140
# Epoch 26, CIFAR-10 Batch 5:  Cost= 0.00288, Validation Accuracy= 0.68520
# Epoch 27, CIFAR-10 Batch 1:  Cost= 0.00501, Validation Accuracy= 0.68740
# Epoch 27, CIFAR-10 Batch 2:  Cost= 0.00289, Validation Accuracy= 0.68880
# Epoch 27, CIFAR-10 Batch 3:  Cost= 0.00274, Validation Accuracy= 0.69060
# Epoch 27, CIFAR-10 Batch 4:  Cost= 0.00394, Validation Accuracy= 0.67280
# Epoch 27, CIFAR-10 Batch 5:  Cost= 0.00403, Validation Accuracy= 0.68420
# Epoch 28, CIFAR-10 Batch 1:  Cost= 0.00471, Validation Accuracy= 0.68560
# Epoch 28, CIFAR-10 Batch 2:  Cost= 0.00170, Validation Accuracy= 0.67440
# Epoch 28, CIFAR-10 Batch 3:  Cost= 0.00115, Validation Accuracy= 0.69000
# Epoch 28, CIFAR-10 Batch 4:  Cost= 0.00266, Validation Accuracy= 0.68260
# Epoch 28, CIFAR-10 Batch 5:  Cost= 0.00283, Validation Accuracy= 0.68240
# Epoch 29, CIFAR-10 Batch 1:  Cost= 0.00340, Validation Accuracy= 0.68480
# Epoch 29, CIFAR-10 Batch 2:  Cost= 0.00204, Validation Accuracy= 0.68720
# Epoch 29, CIFAR-10 Batch 3:  Cost= 0.00563, Validation Accuracy= 0.68480
# Epoch 29, CIFAR-10 Batch 4:  Cost= 0.00655, Validation Accuracy= 0.67980
# Epoch 29, CIFAR-10 Batch 5:  Cost= 0.00151, Validation Accuracy= 0.69340
# Epoch 30, CIFAR-10 Batch 1:  Cost= 0.00442, Validation Accuracy= 0.68920
# Epoch 30, CIFAR-10 Batch 2:  Cost= 0.00233, Validation Accuracy= 0.68040
# Epoch 30, CIFAR-10 Batch 3:  Cost= 0.00220, Validation Accuracy= 0.68440
# Epoch 30, CIFAR-10 Batch 4:  Cost= 0.00163, Validation Accuracy= 0.67620
# Epoch 30, CIFAR-10 Batch 5:  Cost= 0.00175, Validation Accuracy= 0.68940
# Epoch 31, CIFAR-10 Batch 1:  Cost= 0.00409, Validation Accuracy= 0.67820
# Epoch 31, CIFAR-10 Batch 2:  Cost= 0.00049, Validation Accuracy= 0.69020
# Epoch 31, CIFAR-10 Batch 3:  Cost= 0.00130, Validation Accuracy= 0.69520
# Epoch 31, CIFAR-10 Batch 4:  Cost= 0.02252, Validation Accuracy= 0.68400
# Epoch 31, CIFAR-10 Batch 5:  Cost= 0.00147, Validation Accuracy= 0.69040
# Epoch 32, CIFAR-10 Batch 1:  Cost= 0.00377, Validation Accuracy= 0.69120
# Epoch 32, CIFAR-10 Batch 2:  Cost= 0.00188, Validation Accuracy= 0.67940
# Epoch 32, CIFAR-10 Batch 3:  Cost= 0.00064, Validation Accuracy= 0.69860
# Epoch 32, CIFAR-10 Batch 4:  Cost= 0.00092, Validation Accuracy= 0.67940
# Epoch 32, CIFAR-10 Batch 5:  Cost= 0.00226, Validation Accuracy= 0.69280
# Epoch 33, CIFAR-10 Batch 1:  Cost= 0.00276, Validation Accuracy= 0.68280
# Epoch 33, CIFAR-10 Batch 2:  Cost= 0.00167, Validation Accuracy= 0.67180
# Epoch 33, CIFAR-10 Batch 3:  Cost= 0.00116, Validation Accuracy= 0.70040
# Epoch 33, CIFAR-10 Batch 4:  Cost= 0.00316, Validation Accuracy= 0.68420
# Epoch 33, CIFAR-10 Batch 5:  Cost= 0.00019, Validation Accuracy= 0.69840
# Epoch 34, CIFAR-10 Batch 1:  Cost= 0.00511, Validation Accuracy= 0.66920
# Epoch 34, CIFAR-10 Batch 2:  Cost= 0.00498, Validation Accuracy= 0.69640
# Epoch 34, CIFAR-10 Batch 3:  Cost= 0.00304, Validation Accuracy= 0.70080
# Epoch 34, CIFAR-10 Batch 4:  Cost= 0.00601, Validation Accuracy= 0.68000
# Epoch 34, CIFAR-10 Batch 5:  Cost= 0.00116, Validation Accuracy= 0.68960
# Epoch 35, CIFAR-10 Batch 1:  Cost= 0.00465, Validation Accuracy= 0.69640
# Epoch 35, CIFAR-10 Batch 2:  Cost= 0.00084, Validation Accuracy= 0.70360
# Epoch 35, CIFAR-10 Batch 3:  Cost= 0.00091, Validation Accuracy= 0.70060
# Epoch 35, CIFAR-10 Batch 4:  Cost= 0.00236, Validation Accuracy= 0.69760
# Epoch 35, CIFAR-10 Batch 5:  Cost= 0.00184, Validation Accuracy= 0.70820
# Epoch 36, CIFAR-10 Batch 1:  Cost= 0.00151, Validation Accuracy= 0.68500
# Epoch 36, CIFAR-10 Batch 2:  Cost= 0.00153, Validation Accuracy= 0.68400
# Epoch 36, CIFAR-10 Batch 3:  Cost= 0.00083, Validation Accuracy= 0.70840
# Epoch 36, CIFAR-10 Batch 4:  Cost= 0.00364, Validation Accuracy= 0.69640
# Epoch 36, CIFAR-10 Batch 5:  Cost= 0.00158, Validation Accuracy= 0.69920
# Epoch 37, CIFAR-10 Batch 1:  Cost= 0.00119, Validation Accuracy= 0.71320
# Epoch 37, CIFAR-10 Batch 2:  Cost= 0.00191, Validation Accuracy= 0.70780
# Epoch 37, CIFAR-10 Batch 3:  Cost= 0.00049, Validation Accuracy= 0.69120
# Epoch 37, CIFAR-10 Batch 4:  Cost= 0.00401, Validation Accuracy= 0.69080
# Epoch 37, CIFAR-10 Batch 5:  Cost= 0.00072, Validation Accuracy= 0.70620
# Epoch 38, CIFAR-10 Batch 1:  Cost= 0.00169, Validation Accuracy= 0.69280
# Epoch 38, CIFAR-10 Batch 2:  Cost= 0.00159, Validation Accuracy= 0.71120
# Epoch 38, CIFAR-10 Batch 3:  Cost= 0.00090, Validation Accuracy= 0.71400
# Epoch 38, CIFAR-10 Batch 4:  Cost= 0.00206, Validation Accuracy= 0.68820
# Epoch 38, CIFAR-10 Batch 5:  Cost= 0.00105, Validation Accuracy= 0.68260
# Epoch 39, CIFAR-10 Batch 1:  Cost= 0.00172, Validation Accuracy= 0.69740
# Epoch 39, CIFAR-10 Batch 2:  Cost= 0.00113, Validation Accuracy= 0.70400
# Epoch 39, CIFAR-10 Batch 3:  Cost= 0.00076, Validation Accuracy= 0.70880
# Epoch 39, CIFAR-10 Batch 4:  Cost= 0.00203, Validation Accuracy= 0.69280
# Epoch 39, CIFAR-10 Batch 5:  Cost= 0.00200, Validation Accuracy= 0.69220
# Epoch 40, CIFAR-10 Batch 1:  Cost= 0.00101, Validation Accuracy= 0.70180
# Epoch 40, CIFAR-10 Batch 2:  Cost= 0.00064, Validation Accuracy= 0.69300
# Epoch 40, CIFAR-10 Batch 3:  Cost= 0.00216, Validation Accuracy= 0.70460
# Epoch 40, CIFAR-10 Batch 4:  Cost= 0.00175, Validation Accuracy= 0.69620
# Epoch 40, CIFAR-10 Batch 5:  Cost= 0.00110, Validation Accuracy= 0.69800
# Epoch 41, CIFAR-10 Batch 1:  Cost= 0.00236, Validation Accuracy= 0.70980
# Epoch 41, CIFAR-10 Batch 2:  Cost= 0.00216, Validation Accuracy= 0.67700
# Epoch 41, CIFAR-10 Batch 3:  Cost= 0.00244, Validation Accuracy= 0.70100
# Epoch 41, CIFAR-10 Batch 4:  Cost= 0.00366, Validation Accuracy= 0.69680
# Epoch 41, CIFAR-10 Batch 5:  Cost= 0.00320, Validation Accuracy= 0.69540
# Epoch 42, CIFAR-10 Batch 1:  Cost= 0.00159, Validation Accuracy= 0.70080
# Epoch 42, CIFAR-10 Batch 2:  Cost= 0.00118, Validation Accuracy= 0.69320
# Epoch 42, CIFAR-10 Batch 3:  Cost= 0.00273, Validation Accuracy= 0.70200
# Epoch 42, CIFAR-10 Batch 4:  Cost= 0.00139, Validation Accuracy= 0.71060
# Epoch 42, CIFAR-10 Batch 5:  Cost= 0.00083, Validation Accuracy= 0.69860
# Epoch 43, CIFAR-10 Batch 1:  Cost= 0.00119, Validation Accuracy= 0.70520
# Epoch 43, CIFAR-10 Batch 2:  Cost= 0.00111, Validation Accuracy= 0.71060
# Epoch 43, CIFAR-10 Batch 3:  Cost= 0.00145, Validation Accuracy= 0.70780
# Epoch 43, CIFAR-10 Batch 4:  Cost= 0.00285, Validation Accuracy= 0.70980
# Epoch 43, CIFAR-10 Batch 5:  Cost= 0.00105, Validation Accuracy= 0.70240
# Epoch 44, CIFAR-10 Batch 1:  Cost= 0.00118, Validation Accuracy= 0.69700
# Epoch 44, CIFAR-10 Batch 2:  Cost= 0.00149, Validation Accuracy= 0.69820
# Epoch 44, CIFAR-10 Batch 3:  Cost= 0.00129, Validation Accuracy= 0.70900
# Epoch 44, CIFAR-10 Batch 4:  Cost= 0.00279, Validation Accuracy= 0.69340
# Epoch 44, CIFAR-10 Batch 5:  Cost= 0.00116, Validation Accuracy= 0.70660
# Epoch 45, CIFAR-10 Batch 1:  Cost= 0.00215, Validation Accuracy= 0.69620
# Epoch 45, CIFAR-10 Batch 2:  Cost= 0.00041, Validation Accuracy= 0.69360
# Epoch 45, CIFAR-10 Batch 3:  Cost= 0.00120, Validation Accuracy= 0.70000
# Epoch 45, CIFAR-10 Batch 4:  Cost= 0.00272, Validation Accuracy= 0.69840
# Epoch 45, CIFAR-10 Batch 5:  Cost= 0.00066, Validation Accuracy= 0.70000
# Epoch 46, CIFAR-10 Batch 1:  Cost= 0.00076, Validation Accuracy= 0.69980
# Epoch 46, CIFAR-10 Batch 2:  Cost= 0.00685, Validation Accuracy= 0.68240
# Epoch 46, CIFAR-10 Batch 3:  Cost= 0.00099, Validation Accuracy= 0.70020
# Epoch 46, CIFAR-10 Batch 4:  Cost= 0.00120, Validation Accuracy= 0.70580
# Epoch 46, CIFAR-10 Batch 5:  Cost= 0.00051, Validation Accuracy= 0.70000
# Epoch 47, CIFAR-10 Batch 1:  Cost= 0.00058, Validation Accuracy= 0.70800
# Epoch 47, CIFAR-10 Batch 2:  Cost= 0.00254, Validation Accuracy= 0.70300
# Epoch 47, CIFAR-10 Batch 3:  Cost= 0.00034, Validation Accuracy= 0.70600
# Epoch 47, CIFAR-10 Batch 4:  Cost= 0.00339, Validation Accuracy= 0.70640
# Epoch 47, CIFAR-10 Batch 5:  Cost= 0.00302, Validation Accuracy= 0.69880
# Epoch 48, CIFAR-10 Batch 1:  Cost= 0.00156, Validation Accuracy= 0.69260
# Epoch 48, CIFAR-10 Batch 2:  Cost= 0.00202, Validation Accuracy= 0.69620
# Epoch 48, CIFAR-10 Batch 3:  Cost= 0.00114, Validation Accuracy= 0.70560
# Epoch 48, CIFAR-10 Batch 4:  Cost= 0.00159, Validation Accuracy= 0.70840
# Epoch 48, CIFAR-10 Batch 5:  Cost= 0.00116, Validation Accuracy= 0.69360
# Epoch 49, CIFAR-10 Batch 1:  Cost= 0.00099, Validation Accuracy= 0.71300
# Epoch 49, CIFAR-10 Batch 2:  Cost= 0.00224, Validation Accuracy= 0.69120
# Epoch 49, CIFAR-10 Batch 3:  Cost= 0.00054, Validation Accuracy= 0.71200
# Epoch 49, CIFAR-10 Batch 4:  Cost= 0.00329, Validation Accuracy= 0.71000
# Epoch 49, CIFAR-10 Batch 5:  Cost= 0.00034, Validation Accuracy= 0.70620
# Epoch 50, CIFAR-10 Batch 1:  Cost= 0.00169, Validation Accuracy= 0.71540
# Epoch 50, CIFAR-10 Batch 2:  Cost= 0.00355, Validation Accuracy= 0.69400
# Epoch 50, CIFAR-10 Batch 3:  Cost= 0.00232, Validation Accuracy= 0.70800
# Epoch 50, CIFAR-10 Batch 4:  Cost= 0.00144, Validation Accuracy= 0.71840
# Epoch 50, CIFAR-10 Batch 5:  Cost= 0.00010, Validation Accuracy= 0.71020
# Epoch 51, CIFAR-10 Batch 1:  Cost= 0.00159, Validation Accuracy= 0.71060
# Epoch 51, CIFAR-10 Batch 2:  Cost= 0.00040, Validation Accuracy= 0.69380
# Epoch 51, CIFAR-10 Batch 3:  Cost= 0.00087, Validation Accuracy= 0.71580
# Epoch 51, CIFAR-10 Batch 4:  Cost= 0.00045, Validation Accuracy= 0.70780
# Epoch 51, CIFAR-10 Batch 5:  Cost= 0.00030, Validation Accuracy= 0.68480
# Epoch 52, CIFAR-10 Batch 1:  Cost= 0.00051, Validation Accuracy= 0.70240
# Epoch 52, CIFAR-10 Batch 2:  Cost= 0.00207, Validation Accuracy= 0.68300
# Epoch 52, CIFAR-10 Batch 3:  Cost= 0.00113, Validation Accuracy= 0.70040
# Epoch 52, CIFAR-10 Batch 4:  Cost= 0.00103, Validation Accuracy= 0.69640
# Epoch 52, CIFAR-10 Batch 5:  Cost= 0.00047, Validation Accuracy= 0.69400
# Epoch 53, CIFAR-10 Batch 1:  Cost= 0.00138, Validation Accuracy= 0.69520
# Epoch 53, CIFAR-10 Batch 2:  Cost= 0.00043, Validation Accuracy= 0.70320
# Epoch 53, CIFAR-10 Batch 3:  Cost= 0.00108, Validation Accuracy= 0.71280
# Epoch 53, CIFAR-10 Batch 4:  Cost= 0.01064, Validation Accuracy= 0.71500
# Epoch 53, CIFAR-10 Batch 5:  Cost= 0.00077, Validation Accuracy= 0.69720
# Epoch 54, CIFAR-10 Batch 1:  Cost= 0.00290, Validation Accuracy= 0.68940
# Epoch 54, CIFAR-10 Batch 2:  Cost= 0.00239, Validation Accuracy= 0.67640
# Epoch 54, CIFAR-10 Batch 3:  Cost= 0.00241, Validation Accuracy= 0.70700
# Epoch 54, CIFAR-10 Batch 4:  Cost= 0.00262, Validation Accuracy= 0.70000
# Epoch 54, CIFAR-10 Batch 5:  Cost= 0.00039, Validation Accuracy= 0.70660
# Epoch 55, CIFAR-10 Batch 1:  Cost= 0.00109, Validation Accuracy= 0.69660
# Epoch 55, CIFAR-10 Batch 2:  Cost= 0.00217, Validation Accuracy= 0.70320
# Epoch 55, CIFAR-10 Batch 3:  Cost= 0.00051, Validation Accuracy= 0.71140
# Epoch 55, CIFAR-10 Batch 4:  Cost= 0.00128, Validation Accuracy= 0.72100
# Epoch 55, CIFAR-10 Batch 5:  Cost= 0.00048, Validation Accuracy= 0.71100
# Epoch 56, CIFAR-10 Batch 1:  Cost= 0.00059, Validation Accuracy= 0.70500
# Epoch 56, CIFAR-10 Batch 2:  Cost= 0.00008, Validation Accuracy= 0.69900
# Epoch 56, CIFAR-10 Batch 3:  Cost= 0.00050, Validation Accuracy= 0.69980
# Epoch 56, CIFAR-10 Batch 4:  Cost= 0.00053, Validation Accuracy= 0.70700
# Epoch 56, CIFAR-10 Batch 5:  Cost= 0.00001, Validation Accuracy= 0.71660
# Epoch 57, CIFAR-10 Batch 1:  Cost= 0.00038, Validation Accuracy= 0.71440
# Epoch 57, CIFAR-10 Batch 2:  Cost= 0.00008, Validation Accuracy= 0.69320
# Epoch 57, CIFAR-10 Batch 3:  Cost= 0.00046, Validation Accuracy= 0.71840
# Epoch 57, CIFAR-10 Batch 4:  Cost= 0.00117, Validation Accuracy= 0.71500
# Epoch 57, CIFAR-10 Batch 5:  Cost= 0.00034, Validation Accuracy= 0.70620
# Epoch 58, CIFAR-10 Batch 1:  Cost= 0.00076, Validation Accuracy= 0.71240
# Epoch 58, CIFAR-10 Batch 2:  Cost= 0.00080, Validation Accuracy= 0.70180
# Epoch 58, CIFAR-10 Batch 3:  Cost= 0.00016, Validation Accuracy= 0.71640
# Epoch 58, CIFAR-10 Batch 4:  Cost= 0.00146, Validation Accuracy= 0.71660
# Epoch 58, CIFAR-10 Batch 5:  Cost= 0.00157, Validation Accuracy= 0.71900
# Epoch 59, CIFAR-10 Batch 1:  Cost= 0.00175, Validation Accuracy= 0.71160
# Epoch 59, CIFAR-10 Batch 2:  Cost= 0.00076, Validation Accuracy= 0.71140
# Epoch 59, CIFAR-10 Batch 3:  Cost= 0.00267, Validation Accuracy= 0.71300
# Epoch 59, CIFAR-10 Batch 4:  Cost= 0.00128, Validation Accuracy= 0.70880
# Epoch 59, CIFAR-10 Batch 5:  Cost= 0.00167, Validation Accuracy= 0.70600
# Epoch 60, CIFAR-10 Batch 1:  Cost= 0.00095, Validation Accuracy= 0.71160
# Epoch 60, CIFAR-10 Batch 2:  Cost= 0.00030, Validation Accuracy= 0.70700
# Epoch 60, CIFAR-10 Batch 3:  Cost= 0.00112, Validation Accuracy= 0.70180
# Epoch 60, CIFAR-10 Batch 4:  Cost= 0.00271, Validation Accuracy= 0.70780
# Epoch 60, CIFAR-10 Batch 5:  Cost= 0.00229, Validation Accuracy= 0.69980
# Epoch 61, CIFAR-10 Batch 1:  Cost= 0.00142, Validation Accuracy= 0.70700
# Epoch 61, CIFAR-10 Batch 2:  Cost= 0.00142, Validation Accuracy= 0.70180
# Epoch 61, CIFAR-10 Batch 3:  Cost= 0.00208, Validation Accuracy= 0.68980
# Epoch 61, CIFAR-10 Batch 4:  Cost= 0.00067, Validation Accuracy= 0.70500
# Epoch 61, CIFAR-10 Batch 5:  Cost= 0.00054, Validation Accuracy= 0.71740
# Epoch 62, CIFAR-10 Batch 1:  Cost= 0.00006, Validation Accuracy= 0.71720
# Epoch 62, CIFAR-10 Batch 2:  Cost= 0.00110, Validation Accuracy= 0.69500
# Epoch 62, CIFAR-10 Batch 3:  Cost= 0.00037, Validation Accuracy= 0.70740
# Epoch 62, CIFAR-10 Batch 4:  Cost= 0.00159, Validation Accuracy= 0.70640
# Epoch 62, CIFAR-10 Batch 5:  Cost= 0.00029, Validation Accuracy= 0.70640
# Epoch 63, CIFAR-10 Batch 1:  Cost= 0.00110, Validation Accuracy= 0.71500
# Epoch 63, CIFAR-10 Batch 2:  Cost= 0.00102, Validation Accuracy= 0.71940
# Epoch 63, CIFAR-10 Batch 3:  Cost= 0.00156, Validation Accuracy= 0.69660
# Epoch 63, CIFAR-10 Batch 4:  Cost= 0.00145, Validation Accuracy= 0.72300
# Epoch 63, CIFAR-10 Batch 5:  Cost= 0.00042, Validation Accuracy= 0.70720
# Epoch 64, CIFAR-10 Batch 1:  Cost= 0.00083, Validation Accuracy= 0.70800
# Epoch 64, CIFAR-10 Batch 2:  Cost= 0.00092, Validation Accuracy= 0.70720
# Epoch 64, CIFAR-10 Batch 3:  Cost= 0.00037, Validation Accuracy= 0.71120
# Epoch 64, CIFAR-10 Batch 4:  Cost= 0.00051, Validation Accuracy= 0.70960
# Epoch 64, CIFAR-10 Batch 5:  Cost= 0.00059, Validation Accuracy= 0.70300
# Epoch 65, CIFAR-10 Batch 1:  Cost= 0.00100, Validation Accuracy= 0.70100
# Epoch 65, CIFAR-10 Batch 2:  Cost= 0.00025, Validation Accuracy= 0.70480
# Epoch 65, CIFAR-10 Batch 3:  Cost= 0.00004, Validation Accuracy= 0.72060
# Epoch 65, CIFAR-10 Batch 4:  Cost= 0.00127, Validation Accuracy= 0.72020
# Epoch 65, CIFAR-10 Batch 5:  Cost= 0.00153, Validation Accuracy= 0.71200
# Epoch 66, CIFAR-10 Batch 1:  Cost= 0.00048, Validation Accuracy= 0.71720
# Epoch 66, CIFAR-10 Batch 2:  Cost= 0.00059, Validation Accuracy= 0.70880
# Epoch 66, CIFAR-10 Batch 3:  Cost= 0.00255, Validation Accuracy= 0.70560
# Epoch 66, CIFAR-10 Batch 4:  Cost= 0.00045, Validation Accuracy= 0.70720
# Epoch 66, CIFAR-10 Batch 5:  Cost= 0.00144, Validation Accuracy= 0.70620
# Epoch 67, CIFAR-10 Batch 1:  Cost= 0.00004, Validation Accuracy= 0.71160
# Epoch 67, CIFAR-10 Batch 2:  Cost= 0.00070, Validation Accuracy= 0.70960
# Epoch 67, CIFAR-10 Batch 3:  Cost= 0.00009, Validation Accuracy= 0.70800
# Epoch 67, CIFAR-10 Batch 4:  Cost= 0.00044, Validation Accuracy= 0.71620
# Epoch 67, CIFAR-10 Batch 5:  Cost= 0.00205, Validation Accuracy= 0.70940
# Epoch 68, CIFAR-10 Batch 1:  Cost= 0.00060, Validation Accuracy= 0.70420
# Epoch 68, CIFAR-10 Batch 2:  Cost= 0.00157, Validation Accuracy= 0.71080
# Epoch 68, CIFAR-10 Batch 3:  Cost= 0.00030, Validation Accuracy= 0.71560
# Epoch 68, CIFAR-10 Batch 4:  Cost= 0.00068, Validation Accuracy= 0.70180
# Epoch 68, CIFAR-10 Batch 5:  Cost= 0.00077, Validation Accuracy= 0.70820
# Epoch 69, CIFAR-10 Batch 1:  Cost= 0.00055, Validation Accuracy= 0.70240
# Epoch 69, CIFAR-10 Batch 2:  Cost= 0.00088, Validation Accuracy= 0.70860
# Epoch 69, CIFAR-10 Batch 3:  Cost= 0.00009, Validation Accuracy= 0.70840
# Epoch 69, CIFAR-10 Batch 4:  Cost= 0.00006, Validation Accuracy= 0.71020
# Epoch 69, CIFAR-10 Batch 5:  Cost= 0.00020, Validation Accuracy= 0.72060
# Epoch 70, CIFAR-10 Batch 1:  Cost= 0.00049, Validation Accuracy= 0.71120
# Epoch 70, CIFAR-10 Batch 2:  Cost= 0.00019, Validation Accuracy= 0.71600
# Epoch 70, CIFAR-10 Batch 3:  Cost= 0.00100, Validation Accuracy= 0.71800
# Epoch 70, CIFAR-10 Batch 4:  Cost= 0.00079, Validation Accuracy= 0.71400
# Epoch 70, CIFAR-10 Batch 5:  Cost= 0.00025, Validation Accuracy= 0.71580
# Epoch 71, CIFAR-10 Batch 1:  Cost= 0.00087, Validation Accuracy= 0.70720
# Epoch 71, CIFAR-10 Batch 2:  Cost= 0.00033, Validation Accuracy= 0.70560
# Epoch 71, CIFAR-10 Batch 3:  Cost= 0.00015, Validation Accuracy= 0.71560
# Epoch 71, CIFAR-10 Batch 4:  Cost= 0.00042, Validation Accuracy= 0.71740
# Epoch 71, CIFAR-10 Batch 5:  Cost= 0.00139, Validation Accuracy= 0.71500
# Epoch 72, CIFAR-10 Batch 1:  Cost= 0.00044, Validation Accuracy= 0.70240
# Epoch 72, CIFAR-10 Batch 2:  Cost= 0.00026, Validation Accuracy= 0.70760
# Epoch 72, CIFAR-10 Batch 3:  Cost= 0.00016, Validation Accuracy= 0.71340
# Epoch 72, CIFAR-10 Batch 4:  Cost= 0.00025, Validation Accuracy= 0.71620
# Epoch 72, CIFAR-10 Batch 5:  Cost= 0.00025, Validation Accuracy= 0.71240
# Epoch 73, CIFAR-10 Batch 1:  Cost= 0.00029, Validation Accuracy= 0.70840
# Epoch 73, CIFAR-10 Batch 2:  Cost= 0.00034, Validation Accuracy= 0.71660
# Epoch 73, CIFAR-10 Batch 3:  Cost= 0.00081, Validation Accuracy= 0.70740
# Epoch 73, CIFAR-10 Batch 4:  Cost= 0.00088, Validation Accuracy= 0.70620
# Epoch 73, CIFAR-10 Batch 5:  Cost= 0.00125, Validation Accuracy= 0.71640
# Epoch 74, CIFAR-10 Batch 1:  Cost= 0.00063, Validation Accuracy= 0.71140
# Epoch 74, CIFAR-10 Batch 2:  Cost= 0.00206, Validation Accuracy= 0.68700
# Epoch 74, CIFAR-10 Batch 3:  Cost= 0.00042, Validation Accuracy= 0.70780
# Epoch 74, CIFAR-10 Batch 4:  Cost= 0.00042, Validation Accuracy= 0.71020
# Epoch 74, CIFAR-10 Batch 5:  Cost= 0.00180, Validation Accuracy= 0.71200
# Epoch 75, CIFAR-10 Batch 1:  Cost= 0.00074, Validation Accuracy= 0.71260
# Epoch 75, CIFAR-10 Batch 2:  Cost= 0.00037, Validation Accuracy= 0.72040
# Epoch 75, CIFAR-10 Batch 3:  Cost= 0.00000, Validation Accuracy= 0.72420
# Epoch 75, CIFAR-10 Batch 4:  Cost= 0.00084, Validation Accuracy= 0.70520
# Epoch 75, CIFAR-10 Batch 5:  Cost= 0.00083, Validation Accuracy= 0.70960
# Epoch 76, CIFAR-10 Batch 1:  Cost= 0.00104, Validation Accuracy= 0.70360
# Epoch 76, CIFAR-10 Batch 2:  Cost= 0.00091, Validation Accuracy= 0.70720
# Epoch 76, CIFAR-10 Batch 3:  Cost= 0.00003, Validation Accuracy= 0.69400
# Epoch 76, CIFAR-10 Batch 4:  Cost= 0.00127, Validation Accuracy= 0.69900
# Epoch 76, CIFAR-10 Batch 5:  Cost= 0.00164, Validation Accuracy= 0.70600
# Epoch 77, CIFAR-10 Batch 1:  Cost= 0.00062, Validation Accuracy= 0.70240
# Epoch 77, CIFAR-10 Batch 2:  Cost= 0.00033, Validation Accuracy= 0.71520
# Epoch 77, CIFAR-10 Batch 3:  Cost= 0.00001, Validation Accuracy= 0.71560
# Epoch 77, CIFAR-10 Batch 4:  Cost= 0.00014, Validation Accuracy= 0.71240
# Epoch 77, CIFAR-10 Batch 5:  Cost= 0.00038, Validation Accuracy= 0.71280
# Epoch 78, CIFAR-10 Batch 1:  Cost= 0.00140, Validation Accuracy= 0.70440
# Epoch 78, CIFAR-10 Batch 2:  Cost= 0.00151, Validation Accuracy= 0.69320
# Epoch 78, CIFAR-10 Batch 3:  Cost= 0.00016, Validation Accuracy= 0.71020
# Epoch 78, CIFAR-10 Batch 4:  Cost= 0.00006, Validation Accuracy= 0.71620
# Epoch 78, CIFAR-10 Batch 5:  Cost= 0.00310, Validation Accuracy= 0.72160
# Epoch 79, CIFAR-10 Batch 1:  Cost= 0.00197, Validation Accuracy= 0.70720
# Epoch 79, CIFAR-10 Batch 2:  Cost= 0.00057, Validation Accuracy= 0.71760
# Epoch 79, CIFAR-10 Batch 3:  Cost= 0.00014, Validation Accuracy= 0.69920
# Epoch 79, CIFAR-10 Batch 4:  Cost= 0.00054, Validation Accuracy= 0.71220
# Epoch 79, CIFAR-10 Batch 5:  Cost= 0.00005, Validation Accuracy= 0.71320
# Epoch 80, CIFAR-10 Batch 1:  Cost= 0.00171, Validation Accuracy= 0.69180
# Epoch 80, CIFAR-10 Batch 2:  Cost= 0.00062, Validation Accuracy= 0.70380
# Epoch 80, CIFAR-10 Batch 3:  Cost= 0.00196, Validation Accuracy= 0.71120
# Epoch 80, CIFAR-10 Batch 4:  Cost= 0.00123, Validation Accuracy= 0.72100
# Epoch 80, CIFAR-10 Batch 5:  Cost= 0.00019, Validation Accuracy= 0.72040
# Epoch 81, CIFAR-10 Batch 1:  Cost= 0.00117, Validation Accuracy= 0.71080
# Epoch 81, CIFAR-10 Batch 2:  Cost= 0.00010, Validation Accuracy= 0.69840
# Epoch 81, CIFAR-10 Batch 3:  Cost= 0.00043, Validation Accuracy= 0.71300
# Epoch 81, CIFAR-10 Batch 4:  Cost= 0.00040, Validation Accuracy= 0.70480
# Epoch 81, CIFAR-10 Batch 5:  Cost= 0.00044, Validation Accuracy= 0.70460
# Epoch 82, CIFAR-10 Batch 1:  Cost= 0.00096, Validation Accuracy= 0.70260
# Epoch 82, CIFAR-10 Batch 2:  Cost= 0.00006, Validation Accuracy= 0.70940
# Epoch 82, CIFAR-10 Batch 3:  Cost= 0.00034, Validation Accuracy= 0.71960
# Epoch 82, CIFAR-10 Batch 4:  Cost= 0.00007, Validation Accuracy= 0.71180
# Epoch 82, CIFAR-10 Batch 5:  Cost= 0.00001, Validation Accuracy= 0.71540
# Epoch 83, CIFAR-10 Batch 1:  Cost= 0.00028, Validation Accuracy= 0.70400
# Epoch 83, CIFAR-10 Batch 2:  Cost= 0.00018, Validation Accuracy= 0.69400
# Epoch 83, CIFAR-10 Batch 3:  Cost= 0.00004, Validation Accuracy= 0.71040
# Epoch 83, CIFAR-10 Batch 4:  Cost= 0.00052, Validation Accuracy= 0.71340
# Epoch 83, CIFAR-10 Batch 5:  Cost= 0.00053, Validation Accuracy= 0.72180
# Epoch 84, CIFAR-10 Batch 1:  Cost= 0.00086, Validation Accuracy= 0.70300
# Epoch 84, CIFAR-10 Batch 2:  Cost= 0.00052, Validation Accuracy= 0.70860
# Epoch 84, CIFAR-10 Batch 3:  Cost= 0.00082, Validation Accuracy= 0.71800
# Epoch 84, CIFAR-10 Batch 4:  Cost= 0.00123, Validation Accuracy= 0.70740
# Epoch 84, CIFAR-10 Batch 5:  Cost= 0.00091, Validation Accuracy= 0.70740
# Epoch 85, CIFAR-10 Batch 1:  Cost= 0.00009, Validation Accuracy= 0.70740
# Epoch 85, CIFAR-10 Batch 2:  Cost= 0.00013, Validation Accuracy= 0.71720
# Epoch 85, CIFAR-10 Batch 3:  Cost= 0.00017, Validation Accuracy= 0.71220
# Epoch 85, CIFAR-10 Batch 4:  Cost= 0.00113, Validation Accuracy= 0.71280
# Epoch 85, CIFAR-10 Batch 5:  Cost= 0.00038, Validation Accuracy= 0.70780
# Epoch 86, CIFAR-10 Batch 1:  Cost= 0.00023, Validation Accuracy= 0.70460
# Epoch 86, CIFAR-10 Batch 2:  Cost= 0.00037, Validation Accuracy= 0.71700
# Epoch 86, CIFAR-10 Batch 3:  Cost= 0.00207, Validation Accuracy= 0.70340
# Epoch 86, CIFAR-10 Batch 4:  Cost= 0.00096, Validation Accuracy= 0.70260
# Epoch 86, CIFAR-10 Batch 5:  Cost= 0.00010, Validation Accuracy= 0.71880
# Epoch 87, CIFAR-10 Batch 1:  Cost= 0.00019, Validation Accuracy= 0.71520
# Epoch 87, CIFAR-10 Batch 2:  Cost= 0.00027, Validation Accuracy= 0.70080
# Epoch 87, CIFAR-10 Batch 3:  Cost= 0.00111, Validation Accuracy= 0.70940
# Epoch 87, CIFAR-10 Batch 4:  Cost= 0.00023, Validation Accuracy= 0.71220
# Epoch 87, CIFAR-10 Batch 5:  Cost= 0.00026, Validation Accuracy= 0.71400
# Epoch 88, CIFAR-10 Batch 1:  Cost= 0.00003, Validation Accuracy= 0.71400
# Epoch 88, CIFAR-10 Batch 2:  Cost= 0.00001, Validation Accuracy= 0.72200
# Epoch 88, CIFAR-10 Batch 3:  Cost= 0.00083, Validation Accuracy= 0.70520
# Epoch 88, CIFAR-10 Batch 4:  Cost= 0.00131, Validation Accuracy= 0.68540
# Epoch 88, CIFAR-10 Batch 5:  Cost= 0.00043, Validation Accuracy= 0.71800
# Epoch 89, CIFAR-10 Batch 1:  Cost= 0.00028, Validation Accuracy= 0.71380
# Epoch 89, CIFAR-10 Batch 2:  Cost= 0.00042, Validation Accuracy= 0.71800
# Epoch 89, CIFAR-10 Batch 3:  Cost= 0.00033, Validation Accuracy= 0.71900
# Epoch 89, CIFAR-10 Batch 4:  Cost= 0.00033, Validation Accuracy= 0.70700
# Epoch 89, CIFAR-10 Batch 5:  Cost= 0.00087, Validation Accuracy= 0.71440
# Epoch 90, CIFAR-10 Batch 1:  Cost= 0.00080, Validation Accuracy= 0.72240
# Epoch 90, CIFAR-10 Batch 2:  Cost= 0.00003, Validation Accuracy= 0.72000
# Epoch 90, CIFAR-10 Batch 3:  Cost= 0.00079, Validation Accuracy= 0.71860
# Epoch 90, CIFAR-10 Batch 4:  Cost= 0.00003, Validation Accuracy= 0.72180
# Epoch 90, CIFAR-10 Batch 5:  Cost= 0.00009, Validation Accuracy= 0.72160
# Epoch 91, CIFAR-10 Batch 1:  Cost= 0.00015, Validation Accuracy= 0.71720
# Epoch 91, CIFAR-10 Batch 2:  Cost= 0.00054, Validation Accuracy= 0.72620
# Epoch 91, CIFAR-10 Batch 3:  Cost= 0.00075, Validation Accuracy= 0.69840
# Epoch 91, CIFAR-10 Batch 4:  Cost= 0.00190, Validation Accuracy= 0.70700
# Epoch 91, CIFAR-10 Batch 5:  Cost= 0.00004, Validation Accuracy= 0.71580
# Epoch 92, CIFAR-10 Batch 1:  Cost= 0.00131, Validation Accuracy= 0.71180
# Epoch 92, CIFAR-10 Batch 2:  Cost= 0.00035, Validation Accuracy= 0.71400
# Epoch 92, CIFAR-10 Batch 3:  Cost= 0.00029, Validation Accuracy= 0.72000
# Epoch 92, CIFAR-10 Batch 4:  Cost= 0.00037, Validation Accuracy= 0.71740
# Epoch 92, CIFAR-10 Batch 5:  Cost= 0.00056, Validation Accuracy= 0.71180
# Epoch 93, CIFAR-10 Batch 1:  Cost= 0.00038, Validation Accuracy= 0.71560
# Epoch 93, CIFAR-10 Batch 2:  Cost= 0.00011, Validation Accuracy= 0.71680
# Epoch 93, CIFAR-10 Batch 3:  Cost= 0.00020, Validation Accuracy= 0.71660
# Epoch 93, CIFAR-10 Batch 4:  Cost= 0.00110, Validation Accuracy= 0.71340
# Epoch 93, CIFAR-10 Batch 5:  Cost= 0.00032, Validation Accuracy= 0.71660
# Epoch 94, CIFAR-10 Batch 1:  Cost= 0.00098, Validation Accuracy= 0.71760
# Epoch 94, CIFAR-10 Batch 2:  Cost= 0.00063, Validation Accuracy= 0.72040
# Epoch 94, CIFAR-10 Batch 3:  Cost= 0.00010, Validation Accuracy= 0.71700
# Epoch 94, CIFAR-10 Batch 4:  Cost= 0.00117, Validation Accuracy= 0.72300
# Epoch 94, CIFAR-10 Batch 5:  Cost= 0.00003, Validation Accuracy= 0.72040
# Epoch 95, CIFAR-10 Batch 1:  Cost= 0.00040, Validation Accuracy= 0.72200
# Epoch 95, CIFAR-10 Batch 2:  Cost= 0.00007, Validation Accuracy= 0.71540
# Epoch 95, CIFAR-10 Batch 3:  Cost= 0.00110, Validation Accuracy= 0.71020
# Epoch 95, CIFAR-10 Batch 4:  Cost= 0.00083, Validation Accuracy= 0.71860
# Epoch 95, CIFAR-10 Batch 5:  Cost= 0.00062, Validation Accuracy= 0.71240
# Epoch 96, CIFAR-10 Batch 1:  Cost= 0.00004, Validation Accuracy= 0.71660
# Epoch 96, CIFAR-10 Batch 2:  Cost= 0.00017, Validation Accuracy= 0.70960
# Epoch 96, CIFAR-10 Batch 3:  Cost= 0.00093, Validation Accuracy= 0.71840
# Epoch 96, CIFAR-10 Batch 4:  Cost= 0.00167, Validation Accuracy= 0.71040
# Epoch 96, CIFAR-10 Batch 5:  Cost= 0.00025, Validation Accuracy= 0.72600
# Epoch 97, CIFAR-10 Batch 1:  Cost= 0.00048, Validation Accuracy= 0.70720
# Epoch 97, CIFAR-10 Batch 2:  Cost= 0.00054, Validation Accuracy= 0.70860
# Epoch 97, CIFAR-10 Batch 3:  Cost= 0.00005, Validation Accuracy= 0.71360
# Epoch 97, CIFAR-10 Batch 4:  Cost= 0.00071, Validation Accuracy= 0.70720
# Epoch 97, CIFAR-10 Batch 5:  Cost= 0.00005, Validation Accuracy= 0.71020
# Epoch 98, CIFAR-10 Batch 1:  Cost= 0.00034, Validation Accuracy= 0.71500
# Epoch 98, CIFAR-10 Batch 2:  Cost= 0.00044, Validation Accuracy= 0.70800
# Epoch 98, CIFAR-10 Batch 3:  Cost= 0.00010, Validation Accuracy= 0.71280
# Epoch 98, CIFAR-10 Batch 4:  Cost= 0.00033, Validation Accuracy= 0.71360
# Epoch 98, CIFAR-10 Batch 5:  Cost= 0.00031, Validation Accuracy= 0.70480
# Epoch 99, CIFAR-10 Batch 1:  Cost= 0.00007, Validation Accuracy= 0.70900
# Epoch 99, CIFAR-10 Batch 2:  Cost= 0.00000, Validation Accuracy= 0.71920
# Epoch 99, CIFAR-10 Batch 3:  Cost= 0.00021, Validation Accuracy= 0.71380
# Epoch 99, CIFAR-10 Batch 4:  Cost= 0.00108, Validation Accuracy= 0.70840
# Epoch 99, CIFAR-10 Batch 5:  Cost= 0.00010, Validation Accuracy= 0.71540
# Epoch 100, CIFAR-10 Batch 1:  Cost= 0.00034, Validation Accuracy= 0.71340
# Epoch 100, CIFAR-10 Batch 2:  Cost= 0.00026, Validation Accuracy= 0.70760
# Epoch 100, CIFAR-10 Batch 3:  Cost= 0.00093, Validation Accuracy= 0.70580
# Epoch 100, CIFAR-10 Batch 4:  Cost= 0.00063, Validation Accuracy= 0.72380
# Epoch 100, CIFAR-10 Batch 5:  Cost= 0.00032, Validation Accuracy= 0.71760
# Epoch 101, CIFAR-10 Batch 1:  Cost= 0.00015, Validation Accuracy= 0.71980
# Epoch 101, CIFAR-10 Batch 2:  Cost= 0.00036, Validation Accuracy= 0.71120
# Epoch 101, CIFAR-10 Batch 3:  Cost= 0.00089, Validation Accuracy= 0.70820
# Epoch 101, CIFAR-10 Batch 4:  Cost= 0.00077, Validation Accuracy= 0.70960
# Epoch 101, CIFAR-10 Batch 5:  Cost= 0.00015, Validation Accuracy= 0.70600
# Epoch 102, CIFAR-10 Batch 1:  Cost= 0.00020, Validation Accuracy= 0.71920
# Epoch 102, CIFAR-10 Batch 2:  Cost= 0.00128, Validation Accuracy= 0.71300
# Epoch 102, CIFAR-10 Batch 3:  Cost= 0.00029, Validation Accuracy= 0.71360
# Epoch 102, CIFAR-10 Batch 4:  Cost= 0.00071, Validation Accuracy= 0.71720
# Epoch 102, CIFAR-10 Batch 5:  Cost= 0.00009, Validation Accuracy= 0.71540
# Epoch 103, CIFAR-10 Batch 1:  Cost= 0.00036, Validation Accuracy= 0.71140
# Epoch 103, CIFAR-10 Batch 2:  Cost= 0.00005, Validation Accuracy= 0.71500
# Epoch 103, CIFAR-10 Batch 3:  Cost= 0.00052, Validation Accuracy= 0.70600
# Epoch 103, CIFAR-10 Batch 4:  Cost= 0.00064, Validation Accuracy= 0.70900
# Epoch 103, CIFAR-10 Batch 5:  Cost= 0.00048, Validation Accuracy= 0.71460
# Epoch 104, CIFAR-10 Batch 1:  Cost= 0.00107, Validation Accuracy= 0.71520
# Epoch 104, CIFAR-10 Batch 2:  Cost= 0.00059, Validation Accuracy= 0.71020
# Epoch 104, CIFAR-10 Batch 3:  Cost= 0.00018, Validation Accuracy= 0.71760
# Epoch 104, CIFAR-10 Batch 4:  Cost= 0.00054, Validation Accuracy= 0.72020
# Epoch 104, CIFAR-10 Batch 5:  Cost= 0.00004, Validation Accuracy= 0.71120
# Epoch 105, CIFAR-10 Batch 1:  Cost= 0.00052, Validation Accuracy= 0.71840
# Epoch 105, CIFAR-10 Batch 2:  Cost= 0.00038, Validation Accuracy= 0.71540
# Epoch 105, CIFAR-10 Batch 3:  Cost= 0.00044, Validation Accuracy= 0.71540
# Epoch 105, CIFAR-10 Batch 4:  Cost= 0.00115, Validation Accuracy= 0.72900
# Epoch 105, CIFAR-10 Batch 5:  Cost= 0.00008, Validation Accuracy= 0.71960
# Epoch 106, CIFAR-10 Batch 1:  Cost= 0.00005, Validation Accuracy= 0.71640
# Epoch 106, CIFAR-10 Batch 2:  Cost= 0.00004, Validation Accuracy= 0.72020
# Epoch 106, CIFAR-10 Batch 3:  Cost= 0.00158, Validation Accuracy= 0.71660
# Epoch 106, CIFAR-10 Batch 4:  Cost= 0.00259, Validation Accuracy= 0.71540
# Epoch 106, CIFAR-10 Batch 5:  Cost= 0.00018, Validation Accuracy= 0.72100
# Epoch 107, CIFAR-10 Batch 1:  Cost= 0.00059, Validation Accuracy= 0.70600
# Epoch 107, CIFAR-10 Batch 2:  Cost= 0.00052, Validation Accuracy= 0.71920
# Epoch 107, CIFAR-10 Batch 3:  Cost= 0.00038, Validation Accuracy= 0.71760
# Epoch 107, CIFAR-10 Batch 4:  Cost= 0.00017, Validation Accuracy= 0.72100
# Epoch 107, CIFAR-10 Batch 5:  Cost= 0.00027, Validation Accuracy= 0.71360
# Epoch 108, CIFAR-10 Batch 1:  Cost= 0.00008, Validation Accuracy= 0.71180
# Epoch 108, CIFAR-10 Batch 2:  Cost= 0.00004, Validation Accuracy= 0.70640
# Epoch 108, CIFAR-10 Batch 3:  Cost= 0.00056, Validation Accuracy= 0.72480
# Epoch 108, CIFAR-10 Batch 4:  Cost= 0.00051, Validation Accuracy= 0.71220
# Epoch 108, CIFAR-10 Batch 5:  Cost= 0.00097, Validation Accuracy= 0.71640
# Epoch 109, CIFAR-10 Batch 1:  Cost= 0.00009, Validation Accuracy= 0.72100
# Epoch 109, CIFAR-10 Batch 2:  Cost= 0.00183, Validation Accuracy= 0.70960
# Epoch 109, CIFAR-10 Batch 3:  Cost= 0.00032, Validation Accuracy= 0.70220
# Epoch 109, CIFAR-10 Batch 4:  Cost= 0.00022, Validation Accuracy= 0.72160
# Epoch 109, CIFAR-10 Batch 5:  Cost= 0.00071, Validation Accuracy= 0.71540
# Epoch 110, CIFAR-10 Batch 1:  Cost= 0.00020, Validation Accuracy= 0.71780
# Epoch 110, CIFAR-10 Batch 2:  Cost= 0.00062, Validation Accuracy= 0.72060
# Epoch 110, CIFAR-10 Batch 3:  Cost= 0.00114, Validation Accuracy= 0.71640
# Epoch 110, CIFAR-10 Batch 4:  Cost= 0.00106, Validation Accuracy= 0.72480
# Epoch 110, CIFAR-10 Batch 5:  Cost= 0.00070, Validation Accuracy= 0.71340
# Epoch 111, CIFAR-10 Batch 1:  Cost= 0.00152, Validation Accuracy= 0.71520
# Epoch 111, CIFAR-10 Batch 2:  Cost= 0.00097, Validation Accuracy= 0.71540
# Epoch 111, CIFAR-10 Batch 3:  Cost= 0.00004, Validation Accuracy= 0.71820
# Epoch 111, CIFAR-10 Batch 4:  Cost= 0.00016, Validation Accuracy= 0.72660
# Epoch 111, CIFAR-10 Batch 5:  Cost= 0.00025, Validation Accuracy= 0.72200
# Epoch 112, CIFAR-10 Batch 1:  Cost= 0.00026, Validation Accuracy= 0.71920
# Epoch 112, CIFAR-10 Batch 2:  Cost= 0.00035, Validation Accuracy= 0.71800
# Epoch 112, CIFAR-10 Batch 3:  Cost= 0.00025, Validation Accuracy= 0.72120
# Epoch 112, CIFAR-10 Batch 4:  Cost= 0.00103, Validation Accuracy= 0.71840
# Epoch 112, CIFAR-10 Batch 5:  Cost= 0.00011, Validation Accuracy= 0.72340
# Epoch 113, CIFAR-10 Batch 1:  Cost= 0.00021, Validation Accuracy= 0.72400
# Epoch 113, CIFAR-10 Batch 2:  Cost= 0.00070, Validation Accuracy= 0.71900
# Epoch 113, CIFAR-10 Batch 3:  Cost= 0.00067, Validation Accuracy= 0.72260
# Epoch 113, CIFAR-10 Batch 4:  Cost= 0.00005, Validation Accuracy= 0.72000
# Epoch 113, CIFAR-10 Batch 5:  Cost= 0.00022, Validation Accuracy= 0.71480
# Epoch 114, CIFAR-10 Batch 1:  Cost= 0.00000, Validation Accuracy= 0.72260
# Epoch 114, CIFAR-10 Batch 2:  Cost= 0.00092, Validation Accuracy= 0.71520
# Epoch 114, CIFAR-10 Batch 3:  Cost= 0.00000, Validation Accuracy= 0.71720
# Epoch 114, CIFAR-10 Batch 4:  Cost= 0.00050, Validation Accuracy= 0.72320
# Epoch 114, CIFAR-10 Batch 5:  Cost= 0.00162, Validation Accuracy= 0.72000
# Epoch 115, CIFAR-10 Batch 1:  Cost= 0.00001, Validation Accuracy= 0.72340
# Epoch 115, CIFAR-10 Batch 2:  Cost= 0.00034, Validation Accuracy= 0.72540
# Epoch 115, CIFAR-10 Batch 3:  Cost= 0.00114, Validation Accuracy= 0.71220
# Epoch 115, CIFAR-10 Batch 4:  Cost= 0.00085, Validation Accuracy= 0.70700
# Epoch 115, CIFAR-10 Batch 5:  Cost= 0.00084, Validation Accuracy= 0.72900
# Epoch 116, CIFAR-10 Batch 1:  Cost= 0.00009, Validation Accuracy= 0.71320
# Epoch 116, CIFAR-10 Batch 2:  Cost= 0.00012, Validation Accuracy= 0.72860
# Epoch 116, CIFAR-10 Batch 3:  Cost= 0.00001, Validation Accuracy= 0.72280
# Epoch 116, CIFAR-10 Batch 4:  Cost= 0.00004, Validation Accuracy= 0.72740
# Epoch 116, CIFAR-10 Batch 5:  Cost= 0.00001, Validation Accuracy= 0.72160
# Epoch 117, CIFAR-10 Batch 1:  Cost= 0.00037, Validation Accuracy= 0.70780
# Epoch 117, CIFAR-10 Batch 2:  Cost= 0.00003, Validation Accuracy= 0.72500
# Epoch 117, CIFAR-10 Batch 3:  Cost= 0.00066, Validation Accuracy= 0.71540
# Epoch 117, CIFAR-10 Batch 4:  Cost= 0.00017, Validation Accuracy= 0.71860
# Epoch 117, CIFAR-10 Batch 5:  Cost= 0.00034, Validation Accuracy= 0.71940
# Epoch 118, CIFAR-10 Batch 1:  Cost= 0.00069, Validation Accuracy= 0.71960
# Epoch 118, CIFAR-10 Batch 2:  Cost= 0.00030, Validation Accuracy= 0.71240
# Epoch 118, CIFAR-10 Batch 3:  Cost= 0.00080, Validation Accuracy= 0.71780
# Epoch 118, CIFAR-10 Batch 4:  Cost= 0.00209, Validation Accuracy= 0.68460
# Epoch 118, CIFAR-10 Batch 5:  Cost= 0.00065, Validation Accuracy= 0.70540
# Epoch 119, CIFAR-10 Batch 1:  Cost= 0.00090, Validation Accuracy= 0.71580
# Epoch 119, CIFAR-10 Batch 2:  Cost= 0.00080, Validation Accuracy= 0.72920
# Epoch 119, CIFAR-10 Batch 3:  Cost= 0.00015, Validation Accuracy= 0.71760
# Epoch 119, CIFAR-10 Batch 4:  Cost= 0.00075, Validation Accuracy= 0.72460
# Epoch 119, CIFAR-10 Batch 5:  Cost= 0.00068, Validation Accuracy= 0.72600
# Epoch 120, CIFAR-10 Batch 1:  Cost= 0.00005, Validation Accuracy= 0.72480
# Epoch 120, CIFAR-10 Batch 2:  Cost= 0.00018, Validation Accuracy= 0.71560
# Epoch 120, CIFAR-10 Batch 3:  Cost= 0.00003, Validation Accuracy= 0.71860
# Epoch 120, CIFAR-10 Batch 4:  Cost= 0.00025, Validation Accuracy= 0.72860
# Epoch 120, CIFAR-10 Batch 5:  Cost= 0.00406, Validation Accuracy= 0.70820
# Epoch 121, CIFAR-10 Batch 1:  Cost= 0.00003, Validation Accuracy= 0.71860
# Epoch 121, CIFAR-10 Batch 2:  Cost= 0.00127, Validation Accuracy= 0.71400
# Epoch 121, CIFAR-10 Batch 3:  Cost= 0.00038, Validation Accuracy= 0.71280
# Epoch 121, CIFAR-10 Batch 4:  Cost= 0.00070, Validation Accuracy= 0.71500
# Epoch 121, CIFAR-10 Batch 5:  Cost= 0.00017, Validation Accuracy= 0.72260
# Epoch 122, CIFAR-10 Batch 1:  Cost= 0.00019, Validation Accuracy= 0.71440
# Epoch 122, CIFAR-10 Batch 2:  Cost= 0.00085, Validation Accuracy= 0.71620
# Epoch 122, CIFAR-10 Batch 3:  Cost= 0.00012, Validation Accuracy= 0.72200
# Epoch 122, CIFAR-10 Batch 4:  Cost= 0.00011, Validation Accuracy= 0.72500
# Epoch 122, CIFAR-10 Batch 5:  Cost= 0.00022, Validation Accuracy= 0.71740
# Epoch 123, CIFAR-10 Batch 1:  Cost= 0.00002, Validation Accuracy= 0.71720
# Epoch 123, CIFAR-10 Batch 2:  Cost= 0.00022, Validation Accuracy= 0.72200
# Epoch 123, CIFAR-10 Batch 3:  Cost= 0.00039, Validation Accuracy= 0.72240
# Epoch 123, CIFAR-10 Batch 4:  Cost= 0.00000, Validation Accuracy= 0.71800
# Epoch 123, CIFAR-10 Batch 5:  Cost= 0.00008, Validation Accuracy= 0.72560
# Epoch 124, CIFAR-10 Batch 1:  Cost= 0.00051, Validation Accuracy= 0.71440
# Epoch 124, CIFAR-10 Batch 2:  Cost= 0.00016, Validation Accuracy= 0.70740
# Epoch 124, CIFAR-10 Batch 3:  Cost= 0.00010, Validation Accuracy= 0.72620
# Epoch 124, CIFAR-10 Batch 4:  Cost= 0.00060, Validation Accuracy= 0.70940
# Epoch 124, CIFAR-10 Batch 5:  Cost= 0.00005, Validation Accuracy= 0.71860
# Epoch 125, CIFAR-10 Batch 1:  Cost= 0.00034, Validation Accuracy= 0.70700
# Epoch 125, CIFAR-10 Batch 2:  Cost= 0.00003, Validation Accuracy= 0.72440
# Epoch 125, CIFAR-10 Batch 3:  Cost= 0.00044, Validation Accuracy= 0.72640
# Epoch 125, CIFAR-10 Batch 4:  Cost= 0.00003, Validation Accuracy= 0.71580
# Epoch 125, CIFAR-10 Batch 5:  Cost= 0.00034, Validation Accuracy= 0.71860
# Epoch 126, CIFAR-10 Batch 1:  Cost= 0.00016, Validation Accuracy= 0.72620
# Epoch 126, CIFAR-10 Batch 2:  Cost= 0.00070, Validation Accuracy= 0.71740
# Epoch 126, CIFAR-10 Batch 3:  Cost= 0.00027, Validation Accuracy= 0.70940
# Epoch 126, CIFAR-10 Batch 4:  Cost= 0.00003, Validation Accuracy= 0.72060
# Epoch 126, CIFAR-10 Batch 5:  Cost= 0.00027, Validation Accuracy= 0.71400
# Epoch 127, CIFAR-10 Batch 1:  Cost= 0.00005, Validation Accuracy= 0.72760
# Epoch 127, CIFAR-10 Batch 2:  Cost= 0.00009, Validation Accuracy= 0.72400
# Epoch 127, CIFAR-10 Batch 3:  Cost= 0.00131, Validation Accuracy= 0.71740
# Epoch 127, CIFAR-10 Batch 4:  Cost= 0.00075, Validation Accuracy= 0.72000
# Epoch 127, CIFAR-10 Batch 5:  Cost= 0.00009, Validation Accuracy= 0.72320
# Epoch 128, CIFAR-10 Batch 1:  Cost= 0.00005, Validation Accuracy= 0.72640
# Epoch 128, CIFAR-10 Batch 2:  Cost= 0.00003, Validation Accuracy= 0.72760
# Epoch 128, CIFAR-10 Batch 3:  Cost= 0.00039, Validation Accuracy= 0.73160
# Epoch 128, CIFAR-10 Batch 4:  Cost= 0.00078, Validation Accuracy= 0.72100
# Epoch 128, CIFAR-10 Batch 5:  Cost= 0.00026, Validation Accuracy= 0.72420
# Epoch 129, CIFAR-10 Batch 1:  Cost= 0.00049, Validation Accuracy= 0.72420
# Epoch 129, CIFAR-10 Batch 2:  Cost= 0.00029, Validation Accuracy= 0.71980
# Epoch 129, CIFAR-10 Batch 3:  Cost= 0.00014, Validation Accuracy= 0.72340
# Epoch 129, CIFAR-10 Batch 4:  Cost= 0.00003, Validation Accuracy= 0.72940
# Epoch 129, CIFAR-10 Batch 5:  Cost= 0.00452, Validation Accuracy= 0.71880
# Epoch 130, CIFAR-10 Batch 1:  Cost= 0.00007, Validation Accuracy= 0.71960
# Epoch 130, CIFAR-10 Batch 2:  Cost= 0.00077, Validation Accuracy= 0.71320
# Epoch 130, CIFAR-10 Batch 3:  Cost= 0.00014, Validation Accuracy= 0.72580
# Epoch 130, CIFAR-10 Batch 4:  Cost= 0.00038, Validation Accuracy= 0.70840
# Epoch 130, CIFAR-10 Batch 5:  Cost= 0.00002, Validation Accuracy= 0.72000
# Epoch 131, CIFAR-10 Batch 1:  Cost= 0.00011, Validation Accuracy= 0.71440
# Epoch 131, CIFAR-10 Batch 2:  Cost= 0.00042, Validation Accuracy= 0.72220
# Epoch 131, CIFAR-10 Batch 3:  Cost= 0.00030, Validation Accuracy= 0.70880
# Epoch 131, CIFAR-10 Batch 4:  Cost= 0.00008, Validation Accuracy= 0.71920
# Epoch 131, CIFAR-10 Batch 5:  Cost= 0.00020, Validation Accuracy= 0.73060
# Epoch 132, CIFAR-10 Batch 1:  Cost= 0.00006, Validation Accuracy= 0.72240
# Epoch 132, CIFAR-10 Batch 2:  Cost= 0.00003, Validation Accuracy= 0.71980
# Epoch 132, CIFAR-10 Batch 3:  Cost= 0.00079, Validation Accuracy= 0.71880
# Epoch 132, CIFAR-10 Batch 4:  Cost= 0.00141, Validation Accuracy= 0.71940
# Epoch 132, CIFAR-10 Batch 5:  Cost= 0.00004, Validation Accuracy= 0.72420
# Epoch 133, CIFAR-10 Batch 1:  Cost= 0.00010, Validation Accuracy= 0.71240
# Epoch 133, CIFAR-10 Batch 2:  Cost= 0.00225, Validation Accuracy= 0.72180
# Epoch 133, CIFAR-10 Batch 3:  Cost= 0.00015, Validation Accuracy= 0.72860
# Epoch 133, CIFAR-10 Batch 4:  Cost= 0.00093, Validation Accuracy= 0.71460
# Epoch 133, CIFAR-10 Batch 5:  Cost= 0.00046, Validation Accuracy= 0.71820
# Epoch 134, CIFAR-10 Batch 1:  Cost= 0.00023, Validation Accuracy= 0.71260
# Epoch 134, CIFAR-10 Batch 2:  Cost= 0.00053, Validation Accuracy= 0.72120
# Epoch 134, CIFAR-10 Batch 3:  Cost= 0.00074, Validation Accuracy= 0.71880
# Epoch 134, CIFAR-10 Batch 4:  Cost= 0.00006, Validation Accuracy= 0.72140
# Epoch 134, CIFAR-10 Batch 5:  Cost= 0.00002, Validation Accuracy= 0.72920
# Epoch 135, CIFAR-10 Batch 1:  Cost= 0.00017, Validation Accuracy= 0.72580
# Epoch 135, CIFAR-10 Batch 2:  Cost= 0.00014, Validation Accuracy= 0.71980
# Epoch 135, CIFAR-10 Batch 3:  Cost= 0.00048, Validation Accuracy= 0.73000
# Epoch 135, CIFAR-10 Batch 4:  Cost= 0.00005, Validation Accuracy= 0.72360
# Epoch 135, CIFAR-10 Batch 5:  Cost= 0.00057, Validation Accuracy= 0.72240
# Epoch 136, CIFAR-10 Batch 1:  Cost= 0.00004, Validation Accuracy= 0.72360
# Epoch 136, CIFAR-10 Batch 2:  Cost= 0.00045, Validation Accuracy= 0.71280
# Epoch 136, CIFAR-10 Batch 3:  Cost= 0.00041, Validation Accuracy= 0.70160
# Epoch 136, CIFAR-10 Batch 4:  Cost= 0.00047, Validation Accuracy= 0.72740
# Epoch 136, CIFAR-10 Batch 5:  Cost= 0.00066, Validation Accuracy= 0.72020
# Epoch 137, CIFAR-10 Batch 1:  Cost= 0.00008, Validation Accuracy= 0.71000
# Epoch 137, CIFAR-10 Batch 2:  Cost= 0.00008, Validation Accuracy= 0.71140
# Epoch 137, CIFAR-10 Batch 3:  Cost= 0.00028, Validation Accuracy= 0.72380
# Epoch 137, CIFAR-10 Batch 4:  Cost= 0.00003, Validation Accuracy= 0.71960
# Epoch 137, CIFAR-10 Batch 5:  Cost= 0.00118, Validation Accuracy= 0.72180
# Epoch 138, CIFAR-10 Batch 1:  Cost= 0.00018, Validation Accuracy= 0.73000
# Epoch 138, CIFAR-10 Batch 2:  Cost= 0.00020, Validation Accuracy= 0.72240
# Epoch 138, CIFAR-10 Batch 3:  Cost= 0.00001, Validation Accuracy= 0.71700
# Epoch 138, CIFAR-10 Batch 4:  Cost= 0.00023, Validation Accuracy= 0.71340
# Epoch 138, CIFAR-10 Batch 5:  Cost= 0.00022, Validation Accuracy= 0.70500
# Epoch 139, CIFAR-10 Batch 1:  Cost= 0.00013, Validation Accuracy= 0.71880
# Epoch 139, CIFAR-10 Batch 2:  Cost= 0.00002, Validation Accuracy= 0.72020
# Epoch 139, CIFAR-10 Batch 3:  Cost= 0.00044, Validation Accuracy= 0.72740
# Epoch 139, CIFAR-10 Batch 4:  Cost= 0.00021, Validation Accuracy= 0.72040
# Epoch 139, CIFAR-10 Batch 5:  Cost= 0.00156, Validation Accuracy= 0.72120
# Epoch 140, CIFAR-10 Batch 1:  Cost= 0.00036, Validation Accuracy= 0.73160
# Epoch 140, CIFAR-10 Batch 2:  Cost= 0.00000, Validation Accuracy= 0.72720
# Epoch 140, CIFAR-10 Batch 3:  Cost= 0.00004, Validation Accuracy= 0.73900
# Epoch 140, CIFAR-10 Batch 4:  Cost= 0.00076, Validation Accuracy= 0.72400
# Epoch 140, CIFAR-10 Batch 5:  Cost= 0.00003, Validation Accuracy= 0.71840
# Epoch 141, CIFAR-10 Batch 1:  Cost= 0.00003, Validation Accuracy= 0.72540
# Epoch 141, CIFAR-10 Batch 2:  Cost= 0.00041, Validation Accuracy= 0.72880
# Epoch 141, CIFAR-10 Batch 3:  Cost= 0.00040, Validation Accuracy= 0.72400
# Epoch 141, CIFAR-10 Batch 4:  Cost= 0.00131, Validation Accuracy= 0.70940
# Epoch 141, CIFAR-10 Batch 5:  Cost= 0.00025, Validation Accuracy= 0.72480
# Epoch 142, CIFAR-10 Batch 1:  Cost= 0.00008, Validation Accuracy= 0.72080
# Epoch 142, CIFAR-10 Batch 2:  Cost= 0.00007, Validation Accuracy= 0.72080
# Epoch 142, CIFAR-10 Batch 3:  Cost= 0.00011, Validation Accuracy= 0.72680
# Epoch 142, CIFAR-10 Batch 4:  Cost= 0.00127, Validation Accuracy= 0.71460
# Epoch 142, CIFAR-10 Batch 5:  Cost= 0.00043, Validation Accuracy= 0.72200
# Epoch 143, CIFAR-10 Batch 1:  Cost= 0.00009, Validation Accuracy= 0.72920
# Epoch 143, CIFAR-10 Batch 2:  Cost= 0.00004, Validation Accuracy= 0.72760
# Epoch 143, CIFAR-10 Batch 3:  Cost= 0.00002, Validation Accuracy= 0.72120
# Epoch 143, CIFAR-10 Batch 4:  Cost= 0.00219, Validation Accuracy= 0.71920
# Epoch 143, CIFAR-10 Batch 5:  Cost= 0.00073, Validation Accuracy= 0.71960
# Epoch 144, CIFAR-10 Batch 1:  Cost= 0.00169, Validation Accuracy= 0.72520
# Epoch 144, CIFAR-10 Batch 2:  Cost= 0.00025, Validation Accuracy= 0.72360
# Epoch 144, CIFAR-10 Batch 3:  Cost= 0.00002, Validation Accuracy= 0.72760
# Epoch 144, CIFAR-10 Batch 4:  Cost= 0.00004, Validation Accuracy= 0.72540
# Epoch 144, CIFAR-10 Batch 5:  Cost= 0.00033, Validation Accuracy= 0.71460
# Epoch 145, CIFAR-10 Batch 1:  Cost= 0.00011, Validation Accuracy= 0.72840
# Epoch 145, CIFAR-10 Batch 2:  Cost= 0.00021, Validation Accuracy= 0.72280
# Epoch 145, CIFAR-10 Batch 3:  Cost= 0.00006, Validation Accuracy= 0.72240
# Epoch 145, CIFAR-10 Batch 4:  Cost= 0.00004, Validation Accuracy= 0.72340
# Epoch 145, CIFAR-10 Batch 5:  Cost= 0.00046, Validation Accuracy= 0.72800
# Epoch 146, CIFAR-10 Batch 1:  Cost= 0.00005, Validation Accuracy= 0.72760
# Epoch 146, CIFAR-10 Batch 2:  Cost= 0.00003, Validation Accuracy= 0.70980
# Epoch 146, CIFAR-10 Batch 3:  Cost= 0.00004, Validation Accuracy= 0.71220
# Epoch 146, CIFAR-10 Batch 4:  Cost= 0.00070, Validation Accuracy= 0.71280
# Epoch 146, CIFAR-10 Batch 5:  Cost= 0.00028, Validation Accuracy= 0.72740
# Epoch 147, CIFAR-10 Batch 1:  Cost= 0.00001, Validation Accuracy= 0.73040
# Epoch 147, CIFAR-10 Batch 2:  Cost= 0.00050, Validation Accuracy= 0.72580
# Epoch 147, CIFAR-10 Batch 3:  Cost= 0.00026, Validation Accuracy= 0.72160
# Epoch 147, CIFAR-10 Batch 4:  Cost= 0.00005, Validation Accuracy= 0.71840
# Epoch 147, CIFAR-10 Batch 5:  Cost= 0.00007, Validation Accuracy= 0.72860
# Epoch 148, CIFAR-10 Batch 1:  Cost= 0.00003, Validation Accuracy= 0.72040
# Epoch 148, CIFAR-10 Batch 2:  Cost= 0.00099, Validation Accuracy= 0.72620
# Epoch 148, CIFAR-10 Batch 3:  Cost= 0.00000, Validation Accuracy= 0.72520
# Epoch 148, CIFAR-10 Batch 4:  Cost= 0.00330, Validation Accuracy= 0.70860
# Epoch 148, CIFAR-10 Batch 5:  Cost= 0.00098, Validation Accuracy= 0.71200
# Epoch 149, CIFAR-10 Batch 1:  Cost= 0.00062, Validation Accuracy= 0.71880
# Epoch 149, CIFAR-10 Batch 2:  Cost= 0.00014, Validation Accuracy= 0.72700
# Epoch 149, CIFAR-10 Batch 3:  Cost= 0.00002, Validation Accuracy= 0.72740
# Epoch 149, CIFAR-10 Batch 4:  Cost= 0.00008, Validation Accuracy= 0.73220
# Epoch 149, CIFAR-10 Batch 5:  Cost= 0.00041, Validation Accuracy= 0.73260
# Epoch 150, CIFAR-10 Batch 1:  Cost= 0.00039, Validation Accuracy= 0.72960
# Epoch 150, CIFAR-10 Batch 2:  Cost= 0.00015, Validation Accuracy= 0.73260
# Epoch 150, CIFAR-10 Batch 3:  Cost= 0.00002, Validation Accuracy= 0.72440
# Epoch 150, CIFAR-10 Batch 4:  Cost= 0.00014, Validation Accuracy= 0.73600
# Epoch 150, CIFAR-10 Batch 5:  Cost= 0.00026, Validation Accuracy= 0.73180

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.7154865506329114
